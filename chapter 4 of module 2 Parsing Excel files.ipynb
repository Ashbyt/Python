# %% [markdown]
# # Parsing Excel Files
#
# So far in this module, you have learnt how to work with data in the formats that are machine readable,
# such as CSV, JSON and XML.
# The approaches used to import data in those formats are generally standard.
# However, not all data can easily be imported into Python or other programming languages without
# a fair amount of work.
# For example, with data stored in spreadsheets and PDFs.
# In these circumstances, data is generated purely for human consumption.
# The person who generated the data often tries to make it easily readable for human,
# disregarding the importance of releasing it in a machine readable format.
# In the following two chapters, we will look at two other file types, Excel spreadsheets and PDFs.
# We will provide some generic instructions on how to scrape data from these two file types.
# You will find that the scraping process becomes much more difficult and time-consuming.
# But the ultimate goal stays the same, i.e., extracting data and converting it into a machine readable format.
# * * *
#
# ## 1. Introduction to Excel
#
# Excel is a popular spreadsheet application originally
# developed for Windows.
# You can also find free alternatives that run on Mac OS and Linux,
# for example, LibreOffice Calc and OpenOffice Calc can both work with Excel files.
# An Excel document is also called a workbook.
# It is usually saved in a file with either .xlsx extension or .xls extension,
# depending on the Excel version you use.
# A workbook can contain multiple worksheets, each of which is a grid of cells
# where you keep and manipulate the data.
# Those cells are arranged in numbered rows and letter-named columns.
# Excel can display not only tabular data but also data like line graphs, histograms and charts.
# It also provides a set of data analysis functions for statistical, engineering and financial needs.
# Presumably, most of you know what a Excel file looks like.
# If not, please find some Excel files online and have a look or open the Excel file used in this chapter.
#
# There are many ways of manipulating data stored in Excel spreadsheets.
# For instance,
# "[Working with Excel Files in Python](http://www.python-excel.org/)" contains pointers to
# the best information available about working with Excel files in Python.
# The website lists the following Python packages that deal with Excel:
#
# * `openpyxl`: Reads/writes Excel 2010 xlsx/xlsm/xltx/xltm files.
# * `xlsxwriter`: write text, numbers, formulas and hyperlinks to multiple worksheets in an Excel 2007+ XLSX file.
# * `xlrd`: Extracts data from Excel files (.xls and .xlsx, versions 2.0 onwards).
# * `xlwt`: Writes and formats Excel files compatible with Microsoft Excel versions 95 to 2003.
# * `xlutils`: Contains a set of advanced tools for manipulating Excel files (requires `xlrd` and `xlwt`).
#
# You would need to install each separately if you want to use them;
# however, in this chapter we will use Pandas `ExcelFile` class that requires `xlrd` to demonstrate how to
# parse Excel files.
#
# Some tutorials on working with Excel files that might be of your interest:
# * [Working with Excel Spreadsheets](https://automatetheboringstuff.com/chapter12/): It utilizes openyxl to read
# data from spreadsheets. Read the following sections:
#     * Reading Excel Documents 📖
#     * Project: Reading Data from a Spreadsheet 📖
# * [How to read Excel files with Python (xlrd tutorial)](https://www.youtube.com/watch?v=p0DNcTnreuY):
# a Youtube video on extracting data from a simple Excel file. (Optional)
#
#
# This chapter will use a running example to show
# you how to extract data from Excel spreadsheets step-by-step using Pandas.
# The example we use in this chapter is "[Table 2: Nutrition](http://www.unicef.org/sowc2014/numbers/documents/english/EN-FINAL%20Table%202.pdf)" from Unicef's report on
# [The State of the Worlds Children](http://www.unicef.org/sowc2014/numbers/) for 2014.
# The download link is located at the bottom of the webpage.
# Please download the Excel file, and store it in the same folder as where
# the notebook located.
# Its PDF version will be used in the next chapter while we introduce how to scrape data from PDFs.
# For both chapters, our task is to extract the statistic data table on the child's issues of
# underweight, stunting, wasting and overweight prevalence in different countries.
# * * *

# %% [markdown]
# ## 2. Parsing Excel with Pandas
# In this section we will walk through the process of parsing our example Excel file with Pandas.
# A short tutorial on how to use Pandas `read_excel` function and the ExcelFile class  can
# be found at Pandas [webpage on IO](http://pandas.pydata.org/pandas-docs/stable/io.html#io-excel-reader). 📖  (Just read the section "Reading Excel Files".)
#
# Before we start parsing our Excel file,
# we need to first make sure the Python package `xlrd` is installed,
# as Pandas `ExcelFile` class makes use of `xlrd`.
# The `xlrd` package can be run on Linux and Mac as well as Windows.
# Here we assume you use either Linux or Mac.
# If you use Anaconda, you do not need to worry about this,
# as Anaconda includes the most popular Python packages for data analysis, including `xlrd`.
# Otherwise, you might need to install `xlrd` in order to run `read_excel`.
# To install `xlrd`, you can use [pip](https://pypi.python.org/pypi/pip),
# a Python package management system.
# In your command line, simply type
# ```shell
#     pip install xlrd
# ```
#
# Now to start our script,
# we need to import Pandas
# and open our Excel file by creating a Pandas `ExcelFile` object.

# %%
import pandas as pd
excel_data = pd.ExcelFile('SOWC 2014 Stat Tables_Table 2.xlsx')
excel_data

# %% [markdown]
# By running the code above, we have loaded the Excel file as a Pandas' ExcelFile object into Python.
#
# Are we ready to parse our Excel File? Before starting to parse the file,
# we probably need to ask ourselves a couple of questions. For instance,
# * How many sheets does our Excel file have?
# * Which data sheet does contain our data? What is the name of the sheet? Or what is the index of the sheet?

# %% [markdown]
# Unlike CSV files, an Excel file can have multiple worksheets.
# For example, our Excel file contains two worksheets, one contains data notes,
# and the other contains the data we want.
# In order to get our data, we will just pull the sheet with the data we want.
#
# If your Excel file has a couple of worksheets and you can guess the index of
# the worksheet that contains the data you want, or you have been told from which
# worksheet you are going to extract data, you can directly use Panda's
# [`read_excel`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_excel.html#pandas.read_excel)
# fuction
# ```python
#     pandas.read_excel()
# ```
# This function reads an Excel table in a given worksheet into a Pandas DataFrame,
# where you can start further manipulating the data.
#
# However, in some cases, particularly while an Excel file has a lot of worksheets,
# it might be good to view all the sheets by their names.
# So, let's check out what the names of the sheets we have in our Excel file are:

# %%
excel_data.sheet_names
# Out:
# [u'Data Notes', u'Table 2 ']

# %% [markdown]
# There are two worksheets in our Excel file.
# The one that we are looking for is "Table 2 ".
# So, let's read the second worksheet into a Pandas DataFrame.
# Note that there is an extra space in the worksheet name.
# Without this space, running the following parsing code
# will result in the following error
# ```
#     XLRDError: No sheet named <'Table 2'>
# ```

# %%
df = excel_data.parse('Table 2 ')
df
#df.shape
# Out:
#       TABLE 2. NUTRITION                                         Unnamed: 1  \
# NaN                  NaN                               TABLEAU 2. NUTRITION
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN  Countries and areas                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN      FRENCH HEADINGS                                      Pays et zones
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN     SPANISH HEADINGS                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                               FRENCH COUNTRY NAMES
# NaN          Afghanistan                                        Afghanistan
# NaN              Albania                                            Albanie
# NaN              Algeria                                            Algérie
# NaN              Andorra                                            Andorre
# NaN               Angola                                             Angola
# NaN  Antigua and Barbuda                                 Antigua-et-Barbuda
# NaN            Argentina                                          Argentine
# NaN              Armenia                                            Arménie
# NaN            Australia                                          Australie
# NaN              Austria                                           Autriche
# NaN           Azerbaijan                                        Azerbaïdjan
# NaN              Bahamas                                            Bahamas
# NaN              Bahrain                                            Bahreïn
# NaN           Bangladesh                                         Bangladesh
# ..                   ...                                                ...
# NaN                  NaN  Surpoids – Modéré et grave : pourcentage d’enf...
# NaN                  NaN  Couverture totale par la supplémentation en vi...
# NaN                  NaN  Consommation de sel iodé – Pourcentage de foye...
# NaN                  NaN                                                NaN
# NaN                  NaN                    SOURCES PRINCIPALES DES DONNÉES
# NaN                  NaN  Insuffisance pondérale à la naissance – Enquêt...
# NaN                  NaN  Allaitement maternel – EDS, MICS, autres enquê...
# NaN                  NaN  Insuffisance pondérale, retard de croissance, ...
# NaN                  NaN            Supplémentation en vitamine A – UNICEF.
# NaN                  NaN  Consommation en sel iodé – EDS, MICS, autres e...
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
# NaN                  NaN                                                NaN
#
#                                             Unnamed: 2  \
# NaN                                                NaN
# NaN                                 TABLA 2. NUTRICIÓN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                     Países y zonas
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                              SPANISH COUNTRY NAMES
# NaN                                         Afganistán
# NaN                                            Albania
# NaN                                            Argelia
# NaN                                            Andorra
# NaN                                             Angola
# NaN                                  Antigua y Barbuda
# NaN                                          Argentina
# NaN                                            Armenia
# NaN                                          Australia
# NaN                                            Austria
# NaN                                         Azerbaiyán
# NaN                                            Bahamas
# NaN                                            Bahrein
# NaN                                         Bangladesh
# ..                                                 ...
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                    DEFINICIONES DE LOS INDICADORES
# NaN  Bajo peso al nacer – Porcentaje de lactantes q...
# NaN  Iniciación temprana a la lactancia materna – P...
# NaN  Lactancia materna exclusiva (<6 meses) – Porce...
# NaN  Incorporación de alimentos sólidos, semisólido...
# NaN  Lactancia materna a los 2 años – Porcentaje de...
# NaN  Insuficiencia ponderal – Moderada y grave: Por...
# NaN  Cortedad de talla – Moderada y grave: Porcenta...
# NaN  Emaciación – Moderada y grave: Porcentaje de n...
# NaN  Sobrepeso – Moderado y grave: Porcentaje de ni...
# NaN  Suplementos de vitamina A (cobertura completa)...
# NaN  Consumo de sal yodada – Porcentaje de hogares ...
# NaN                                                NaN
# NaN                   FUENTES ESTADÍSTICAS PRINCIPALES
# NaN  Bajo peso al nacer – Encuestas de Demografía y...
# NaN  Lactancia materna – DHS, MICS, otras encuestas...
# NaN  Insuficiencia ponderal, emaciación, cortedad d...
# NaN                Suplementos de vitamina A – UNICEF.
# NaN  Consumo de sal yodada – DHS, MICS, otras encue...
#
#                                          Unnamed: 3 Unnamed: 4  \
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                             Low birthweight (%)        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                      2008–2012*        NaN
# NaN  Insuffisance\npondérale à la\nnaissance\n(%)\n        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                      2008–2012*        NaN
# NaN                         Bajo peso al nacer (%)         NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                      2008–2012*        NaN
# NaN                                             NaN        NaN
# NaN                                               –        NaN
# NaN                                             3.6        NaN
# NaN                                               6          x
# NaN                                               –        NaN
# NaN                                              12          x
# NaN                                               5          x
# NaN                                             7.2        NaN
# NaN                                               8        NaN
# NaN                                               7          x
# NaN                                               7          x
# NaN                                              10          x
# NaN                                              11          x
# NaN                                               –        NaN
# NaN                                              22          x
# ..                                              ...        ...
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
#
#                                          Unnamed: 5 Unnamed: 6  \
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN           Early initiation of breastfeeding (%)        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                      2008–2012*        NaN
# NaN      Initiation\nprécoce de\nl’allaitement\n(%)        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                      2008−2012*        NaN
# NaN  Iniciación temprana a la lactancia materna (%)        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                      2008−2012*        NaN
# NaN                                             NaN        NaN
# NaN                                               –        NaN
# NaN                                            42.9        NaN
# NaN                                            49.5          x
# NaN                                               –        NaN
# NaN                                            54.9          x
# NaN                                               –        NaN
# NaN                                               –        NaN
# NaN                                            35.7        NaN
# NaN                                               –        NaN
# NaN                                               –        NaN
# NaN                                            31.9          x
# NaN                                               –        NaN
# NaN                                               –        NaN
# NaN                                            47.1        NaN
# ..                                              ...        ...
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
#
#                                            Unnamed: 7 Unnamed: 8  \
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN            Exclusive breastfeeding\n<6 months (%)        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN  Allaitement\nexclusivement\nau sein <6 mois\n(%)        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN         Lactancia materna exclusiva\n<6 meses (%)        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                                 –        NaN
# NaN                                              38.6        NaN
# NaN                                                 7          x
# NaN                                                 –        NaN
# NaN                                                11          x
# NaN                                                 –        NaN
# NaN                                                54        NaN
# NaN                                              34.6        NaN
# NaN                                                 –        NaN
# NaN                                                 –        NaN
# NaN                                                12          x
# NaN                                                 –        NaN
# NaN                                                 –        NaN
# NaN                                              64.1        NaN
# ..                                                ...        ...
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
#
#                                             Unnamed: 9     ...      \
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN  Introduction of solid, semi-solid or soft food...     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN  Introduction\nd’aliments\nsolides, semisolides...     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN  Incorporación de alimentos sóli- dos, semisóli...     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                 29     ...
# NaN                                            78.2788     ...
# NaN                                                 39     ...
# NaN                                                  –     ...
# NaN                                               77.2     ...
# NaN                                                  –     ...
# NaN                                                  –     ...
# NaN                                                 75     ...
# NaN                                                  –     ...
# NaN                                                  –     ...
# NaN                                            83.2918     ...
# NaN                                                  –     ...
# NaN                                                  –     ...
# NaN                                                 62     ...
# ..                                                 ...     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
#
#     Unnamed: 18             Unnamed: 19 Unnamed: 20           Unnamed: 21  \
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN             Wasting (%)         NaN        Overweight (%)
# NaN         NaN  moderate \nand severeθ         NaN  moderate and severeθ
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN        Émaciation (%)\n         NaN        Surpoids (%)\n
# NaN         NaN       modérée et graveθ         NaN     modérée et graveθ
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN          Emaciación (%)         NaN         Sobrepeso (%)
# NaN         NaN       moderada y graveθ         NaN     moderada y graveθ
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN           x                       9           x                   4.6
# NaN         NaN                       9         NaN                  21.7
# NaN           x                       4           x                  12.9
# NaN         NaN                       –         NaN                     –
# NaN           x                     8.2           x                     –
# NaN         NaN                       –         NaN                     –
# NaN           x                     1.2           x                   9.9
# NaN         NaN                       4         NaN                  15.3
# NaN         NaN                       –         NaN                     –
# NaN         NaN                       –         NaN                     –
# NaN           x                       7           x                  12.9
# NaN         NaN                       –         NaN                     –
# NaN         NaN                       –         NaN                     –
# NaN         NaN                    15.6         NaN                   1.5
# ..          ...                     ...         ...                   ...
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
# NaN         NaN                     NaN         NaN                   NaN
#
#     Unnamed: 22                                        Unnamed: 23  \
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN      Vitamin A supplementation, full coverageΔ (%)
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                               2012
# NaN         NaN  Couverture\ntotale par la\nsupplémentation en\...
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                               2012
# NaN         NaN  Suplementos de vitamina A cobertura completa Δ...
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                               2012
# NaN         NaN                                                NaN
# NaN           x                                                  –
# NaN         NaN                                                  –
# NaN           x                                                  –
# NaN         NaN                                                  –
# NaN         NaN                                                 44
# NaN         NaN                                                  –
# NaN           x                                                  –
# NaN         NaN                                                  –
# NaN         NaN                                                  –
# NaN         NaN                                                  –
# NaN           x                                                 90
# NaN         NaN                                                  –
# NaN         NaN                                                  –
# NaN         NaN                                                 99
# ..          ...                                                ...
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
# NaN         NaN                                                NaN
#
#     Unnamed: 24                    Unnamed: 25 Unnamed: 26 Unnamed: 27
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN   Iodized salt consumption (%)         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                     2008–2012*         NaN         NaN
# NaN         NaN  Consommation\nde sel iodé (%)         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                     2008–2012*         NaN         NaN
# NaN         NaN      Consumo de sal yodada (%)         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                     2008–2012*         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                           20.4         NaN         NaN
# NaN         NaN                           75.6         NaN         NaN
# NaN         NaN                           60.7           x         NaN
# NaN         NaN                              –         NaN         NaN
# NaN         NaN                           44.7           x         NaN
# NaN         NaN                              –         NaN         NaN
# NaN         NaN                              –         NaN         NaN
# NaN         NaN                             97           x         NaN
# NaN         NaN                              –         NaN         NaN
# NaN         NaN                              –         NaN         NaN
# NaN           w                           53.8           x         NaN
# NaN         NaN                              –         NaN         NaN
# NaN         NaN                              –         NaN         NaN
# NaN         NaN                           82.3           y         NaN
# ..          ...                            ...         ...         ...
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
# NaN         NaN                            NaN         NaN         NaN
#
# [322 rows x 28 columns]

# %% [markdown]
# We have loaded the target worksheet into Python.
# There are 322 rows and 28 columns (You can use `df.shape` to
# see the dimensionality of the DataFrame).
#
# If you scroll through the output, you will notice that the loaded data table is quite messy.
# The messiness includes
# * Rows only contain missing values that are indicated by NaN in Pandas DataFrame.
# * Column heads are in three languages, i.e., English, French and Spanish.
# * Column heads in one language spread over multiple rows.
# * Country names also appear in three languages.
# * Notes shown in the original Excel file appear in rows towards the end of the data frame.
#
# Remember that our goal is to extract the data table in English.
# It is clear that we need to further process the data frame.
# For demonstration purpose,
# we will try to keep the example as simple as possible,
# so we will not extract column heads here.
# Instead, if you are interested in programmatically extracting column heads,
# you can try it by yourself.
#
# We will start with removing country names in French and Spanish,
# which corresponds to remove two columns, labeled "Unnamed: 1" and "Unnamed: 2" in our data frame.
# To do this, we are going to use DataFrame's [`drop()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html) function,
# which returns a new object with labels in requested axis removed.
# We will frequently use this function later in this section.

# %%
df = df.drop(['Unnamed: 1', 'Unnamed: 2'], 1)

# %%
df.shape
# Out:
# (322, 26)

# %% [markdown]
# Now you should have 26 columns.
# Next we are going to remove all the rows and columns that are empty, i.e., only contains NaNs.

# %%
df = df.dropna(0, how = 'all')
df = df.dropna(1, how = 'all')
df
# Out:
#                                     TABLE 2. NUTRITION  \
# NaN                                Countries and areas
# NaN                                                NaN
# NaN                                                NaN
# NaN                                    FRENCH HEADINGS
# NaN                                                NaN
# NaN                                                NaN
# NaN                                   SPANISH HEADINGS
# NaN                                                NaN
# NaN                                                NaN
# NaN                                        Afghanistan
# NaN                                            Albania
# NaN                                            Algeria
# NaN                                            Andorra
# NaN                                             Angola
# NaN                                Antigua and Barbuda
# NaN                                          Argentina
# NaN                                            Armenia
# NaN                                          Australia
# NaN                                            Austria
# NaN                                         Azerbaijan
# NaN                                            Bahamas
# NaN                                            Bahrain
# NaN                                         Bangladesh
# NaN                                           Barbados
# NaN                                            Belarus
# NaN                                            Belgium
# NaN                                             Belize
# NaN                                              Benin
# NaN                                             Bhutan
# NaN                   Bolivia (Plurinational State of)
# ..                                                 ...
# NaN                          Least developed countries
# NaN                                              World
# NaN  # For a complete list of countries and areas i...
# NaN                                              NOTES
# NaN                              – Data not available.
# NaN  w Identifies countries with national vitamin A...
# NaN  x Data refer to years or periods other than th...
# NaN  y Data differ from the standard definition or ...
# NaN  Δ Full coverage with vitamin A supplements is ...
# NaN  * Data refer to the most recent year available...
# NaN                                 ** Excludes China.
# NaN  θ Regional averages for underweight (moderate ...
# NaN                      DEFINITIONS OF THE INDICATORS
# NaN  Low birthweight – Percentage of infants weighi...
# NaN  Early initiation of breastfeeding – Percentage...
# NaN  Exclusive breastfeeding <6 months – Percentage...
# NaN  Introduction of solid, semi-solid or soft food...
# NaN  Breastfeeding at age 2 – Percentage of childre...
# NaN  Underweight – Moderate and severe: Percentage ...
# NaN  Stunting – Moderate and severe: Percentage of ...
# NaN  Wasting – Moderate and severe: Percentage of c...
# NaN  Overweight – Moderate and severe: Percentage o...
# NaN  Vitamin A supplementation, full coverage – The...
# NaN  Iodized salt consumption – Percentage of house...
# NaN                                  MAIN DATA SOURCES
# NaN  Low birthweight – Demographic and Health Surve...
# NaN  Breastfeeding – DHS, MICS, other national hous...
# NaN  Underweight, stunting, wasting and overweight ...
# NaN                Vitamin A supplementation – UNICEF.
# NaN  Iodized salt consumption – DHS, MICS, other na...
#
#                                          Unnamed: 3 Unnamed: 4  \
# NaN                             Low birthweight (%)        NaN
# NaN                                             NaN        NaN
# NaN                                      2008–2012*        NaN
# NaN  Insuffisance\npondérale à la\nnaissance\n(%)\n        NaN
# NaN                                             NaN        NaN
# NaN                                      2008–2012*        NaN
# NaN                         Bajo peso al nacer (%)         NaN
# NaN                                             NaN        NaN
# NaN                                      2008–2012*        NaN
# NaN                                               –        NaN
# NaN                                             3.6        NaN
# NaN                                               6          x
# NaN                                               –        NaN
# NaN                                              12          x
# NaN                                               5          x
# NaN                                             7.2        NaN
# NaN                                               8        NaN
# NaN                                               7          x
# NaN                                               7          x
# NaN                                              10          x
# NaN                                              11          x
# NaN                                               –        NaN
# NaN                                              22          x
# NaN                                            11.8        NaN
# NaN                                               4          x
# NaN                                               –        NaN
# NaN                                            11.1        NaN
# NaN                                              15          x
# NaN                                             9.9        NaN
# NaN                                               6        NaN
# ..                                              ...        ...
# NaN                                         12.8291        NaN
# NaN                                         14.6574        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
#
#                                          Unnamed: 5 Unnamed: 6  \
# NaN           Early initiation of breastfeeding (%)        NaN
# NaN                                             NaN        NaN
# NaN                                      2008–2012*        NaN
# NaN      Initiation\nprécoce de\nl’allaitement\n(%)        NaN
# NaN                                             NaN        NaN
# NaN                                      2008−2012*        NaN
# NaN  Iniciación temprana a la lactancia materna (%)        NaN
# NaN                                             NaN        NaN
# NaN                                      2008−2012*        NaN
# NaN                                               –        NaN
# NaN                                            42.9        NaN
# NaN                                            49.5          x
# NaN                                               –        NaN
# NaN                                            54.9          x
# NaN                                               –        NaN
# NaN                                               –        NaN
# NaN                                            35.7        NaN
# NaN                                               –        NaN
# NaN                                               –        NaN
# NaN                                            31.9          x
# NaN                                               –        NaN
# NaN                                               –        NaN
# NaN                                            47.1        NaN
# NaN                                               –        NaN
# NaN                                            21.1          x
# NaN                                               –        NaN
# NaN                                            61.5        NaN
# NaN                                            50.4        NaN
# NaN                                              59        NaN
# NaN                                            63.8        NaN
# ..                                              ...        ...
# NaN                                         53.3585        NaN
# NaN                                         43.2414        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
# NaN                                             NaN        NaN
#
#                                            Unnamed: 7 Unnamed: 8  \
# NaN            Exclusive breastfeeding\n<6 months (%)        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN  Allaitement\nexclusivement\nau sein <6 mois\n(%)        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN         Lactancia materna exclusiva\n<6 meses (%)        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                                 –        NaN
# NaN                                              38.6        NaN
# NaN                                                 7          x
# NaN                                                 –        NaN
# NaN                                                11          x
# NaN                                                 –        NaN
# NaN                                                54        NaN
# NaN                                              34.6        NaN
# NaN                                                 –        NaN
# NaN                                                 –        NaN
# NaN                                                12          x
# NaN                                                 –        NaN
# NaN                                                 –        NaN
# NaN                                              64.1        NaN
# NaN                                                 –        NaN
# NaN                                                 9          x
# NaN                                                 –        NaN
# NaN                                              14.7        NaN
# NaN                                              32.5        NaN
# NaN                                              48.7        NaN
# NaN                                              60.4        NaN
# ..                                                ...        ...
# NaN                                            48.121        NaN
# NaN                                                38        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
# NaN                                               NaN        NaN
#
#                                             Unnamed: 9 Unnamed: 10  \
# NaN  Introduction of solid, semi-solid or soft food...         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN  Introduction\nd’aliments\nsolides, semisolides...         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN  Incorporación de alimentos sóli- dos, semisóli...         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                 29           x
# NaN                                            78.2788         NaN
# NaN                                                 39         x,y
# NaN                                                  –         NaN
# NaN                                               77.2           x
# NaN                                                  –         NaN
# NaN                                                  –         NaN
# NaN                                                 75         NaN
# NaN                                                  –         NaN
# NaN                                                  –         NaN
# NaN                                            83.2918           x
# NaN                                                  –         NaN
# NaN                                                  –         NaN
# NaN                                                 62         NaN
# NaN                                                  –         NaN
# NaN                                               38.3           x
# NaN                                                  –         NaN
# NaN                                               68.5         NaN
# NaN                                               76.3           y
# NaN                                               66.7         NaN
# NaN                                             82.555         NaN
# ..                                                 ...         ...
# NaN                                                 63         NaN
# NaN                                            54.8513         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
#
#                                 Unnamed: 11     ...      \
# NaN              Breastfeeding at age 2 (%)     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN  Nourris au sein\nà l’âge de\n2 ans (%)     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN      Lactancia materna a los 2 anos (%)     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                      54     ...
# NaN                                      31     ...
# NaN                                    22.2     ...
# NaN                                       –     ...
# NaN                                      37     ...
# NaN                                       –     ...
# NaN                                      28     ...
# NaN                                    22.8     ...
# NaN                                       –     ...
# NaN                                       –     ...
# NaN                                    16.2     ...
# NaN                                       –     ...
# NaN                                       –     ...
# NaN                                    89.6     ...
# NaN                                       –     ...
# NaN                                     3.6     ...
# NaN                                       –     ...
# NaN                                    34.9     ...
# NaN                                    92.1     ...
# NaN                                    65.7     ...
# NaN                                    39.8     ...
# ..                                      ...     ...
# NaN                                 63.8288     ...
# NaN                                 58.0455     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
# NaN                                     NaN     ...
#
#                      Unnamed: 17 Unnamed: 18             Unnamed: 19  \
# NaN                 Stunting (%)         NaN             Wasting (%)
# NaN       moderate \nand severeθ         NaN  moderate \nand severeθ
# NaN                          NaN         NaN                     NaN
# NaN  Retard de\ncroissance (%)\n         NaN        Émaciation (%)\n
# NaN            modérée et graveθ         NaN       modérée et graveθ
# NaN                          NaN         NaN                     NaN
# NaN       Cortedad de\ntalla (%)         NaN          Emaciación (%)
# NaN            moderada y graveθ         NaN       moderada y graveθ
# NaN                          NaN         NaN                     NaN
# NaN                           59           x                       9
# NaN                           19         NaN                       9
# NaN                           15           x                       4
# NaN                            –         NaN                       –
# NaN                           29           x                     8.2
# NaN                            –         NaN                       –
# NaN                          8.2           x                     1.2
# NaN                         19.3         NaN                       4
# NaN                            –         NaN                       –
# NaN                            –         NaN                       –
# NaN                           25           x                       7
# NaN                            –         NaN                       –
# NaN                            –         NaN                       –
# NaN                         41.3         NaN                    15.6
# NaN                            –         NaN                       –
# NaN                            4           x                       2
# NaN                            –         NaN                       –
# NaN                         19.3         NaN                     3.3
# NaN                         44.6         NaN                      16
# NaN                         33.5         NaN                     5.9
# NaN                         27.1         NaN                     1.4
# ..                           ...         ...                     ...
# NaN                         37.4         NaN                     9.7
# NaN                         24.7         NaN                     7.8
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
# NaN                          NaN         NaN                     NaN
#
#     Unnamed: 20           Unnamed: 21 Unnamed: 22  \
# NaN         NaN        Overweight (%)         NaN
# NaN         NaN  moderate and severeθ         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN        Surpoids (%)\n         NaN
# NaN         NaN     modérée et graveθ         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN         Sobrepeso (%)         NaN
# NaN         NaN     moderada y graveθ         NaN
# NaN         NaN                   NaN         NaN
# NaN           x                   4.6           x
# NaN         NaN                  21.7         NaN
# NaN           x                  12.9           x
# NaN         NaN                     –         NaN
# NaN           x                     –         NaN
# NaN         NaN                     –         NaN
# NaN           x                   9.9           x
# NaN         NaN                  15.3         NaN
# NaN         NaN                     –         NaN
# NaN         NaN                     –         NaN
# NaN           x                  12.9           x
# NaN         NaN                     –         NaN
# NaN         NaN                     –         NaN
# NaN         NaN                   1.5         NaN
# NaN         NaN                     –         NaN
# NaN           x                   9.7           x
# NaN         NaN                     –         NaN
# NaN         NaN                   7.9         NaN
# NaN         NaN                  17.9         NaN
# NaN         NaN                   7.6         NaN
# NaN         NaN                   8.5         NaN
# ..          ...                   ...         ...
# NaN         NaN                   4.5         NaN
# NaN         NaN                   6.7         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
# NaN         NaN                   NaN         NaN
#
#                                            Unnamed: 23 Unnamed: 24  \
# NaN      Vitamin A supplementation, full coverageΔ (%)         NaN
# NaN                                                NaN         NaN
# NaN                                               2012         NaN
# NaN  Couverture\ntotale par la\nsupplémentation en\...         NaN
# NaN                                                NaN         NaN
# NaN                                               2012         NaN
# NaN  Suplementos de vitamina A cobertura completa Δ...         NaN
# NaN                                                NaN         NaN
# NaN                                               2012         NaN
# NaN                                                  –         NaN
# NaN                                                  –         NaN
# NaN                                                  –         NaN
# NaN                                                  –         NaN
# NaN                                                 44         NaN
# NaN                                                  –         NaN
# NaN                                                  –         NaN
# NaN                                                  –         NaN
# NaN                                                  –         NaN
# NaN                                                  –         NaN
# NaN                                                 90           w
# NaN                                                  –         NaN
# NaN                                                  –         NaN
# NaN                                                 99         NaN
# NaN                                                  –         NaN
# NaN                                                  –         NaN
# NaN                                                  –         NaN
# NaN                                                  –         NaN
# NaN                                                 99         NaN
# NaN                                                 43         NaN
# NaN                                                 41         NaN
# ..                                                 ...         ...
# NaN                                            70.4635         NaN
# NaN                                            69.8144          **
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
# NaN                                                NaN         NaN
#
#                        Unnamed: 25 Unnamed: 26
# NaN   Iodized salt consumption (%)         NaN
# NaN                            NaN         NaN
# NaN                     2008–2012*         NaN
# NaN  Consommation\nde sel iodé (%)         NaN
# NaN                            NaN         NaN
# NaN                     2008–2012*         NaN
# NaN      Consumo de sal yodada (%)         NaN
# NaN                            NaN         NaN
# NaN                     2008–2012*         NaN
# NaN                           20.4         NaN
# NaN                           75.6         NaN
# NaN                           60.7           x
# NaN                              –         NaN
# NaN                           44.7           x
# NaN                              –         NaN
# NaN                              –         NaN
# NaN                             97           x
# NaN                              –         NaN
# NaN                              –         NaN
# NaN                           53.8           x
# NaN                              –         NaN
# NaN                              –         NaN
# NaN                           82.3           y
# NaN                              –         NaN
# NaN                              –         NaN
# NaN                              –         NaN
# NaN                              –         NaN
# NaN                             86         NaN
# NaN                           96.2         x,y
# NaN                           88.7           y
# ..                             ...         ...
# NaN                        60.2242         NaN
# NaN                        75.5568         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
# NaN                            NaN         NaN
#
# [245 rows x 25 columns]

# %% [markdown]
# Here we used the [`dropna`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.dropna.html) function of DataFrame. The first argument is axis (0 means row, and 1 means column),
# and the second argument indicates deleting rows/columns with all NaNs.
# We further removed 77 rows and 1 column.
#
# The printout shows that
# the very first column in the data frame only contains NaNs.
# These NaNs are row indices.
# We cannot delete it directly.
# Instead, we are going to reset the row indices with a list of integers.

# %%
df.index = xrange(len(df.index))
df
# Out:
#                                     TABLE 2. NUTRITION  \
# 0                                  Countries and areas
# 1                                                  NaN
# 2                                                  NaN
# 3                                      FRENCH HEADINGS
# 4                                                  NaN
# 5                                                  NaN
# 6                                     SPANISH HEADINGS
# 7                                                  NaN
# 8                                                  NaN
# 9                                          Afghanistan
# 10                                             Albania
# 11                                             Algeria
# 12                                             Andorra
# 13                                              Angola
# 14                                 Antigua and Barbuda
# 15                                           Argentina
# 16                                             Armenia
# 17                                           Australia
# 18                                             Austria
# 19                                          Azerbaijan
# 20                                             Bahamas
# 21                                             Bahrain
# 22                                          Bangladesh
# 23                                            Barbados
# 24                                             Belarus
# 25                                             Belgium
# 26                                              Belize
# 27                                               Benin
# 28                                              Bhutan
# 29                    Bolivia (Plurinational State of)
# ..                                                 ...
# 215                          Least developed countries
# 216                                              World
# 217  # For a complete list of countries and areas i...
# 218                                              NOTES
# 219                              – Data not available.
# 220  w Identifies countries with national vitamin A...
# 221  x Data refer to years or periods other than th...
# 222  y Data differ from the standard definition or ...
# 223  Δ Full coverage with vitamin A supplements is ...
# 224  * Data refer to the most recent year available...
# 225                                 ** Excludes China.
# 226  θ Regional averages for underweight (moderate ...
# 227                      DEFINITIONS OF THE INDICATORS
# 228  Low birthweight – Percentage of infants weighi...
# 229  Early initiation of breastfeeding – Percentage...
# 230  Exclusive breastfeeding <6 months – Percentage...
# 231  Introduction of solid, semi-solid or soft food...
# 232  Breastfeeding at age 2 – Percentage of childre...
# 233  Underweight – Moderate and severe: Percentage ...
# 234  Stunting – Moderate and severe: Percentage of ...
# 235  Wasting – Moderate and severe: Percentage of c...
# 236  Overweight – Moderate and severe: Percentage o...
# 237  Vitamin A supplementation, full coverage – The...
# 238  Iodized salt consumption – Percentage of house...
# 239                                  MAIN DATA SOURCES
# 240  Low birthweight – Demographic and Health Surve...
# 241  Breastfeeding – DHS, MICS, other national hous...
# 242  Underweight, stunting, wasting and overweight ...
# 243                Vitamin A supplementation – UNICEF.
# 244  Iodized salt consumption – DHS, MICS, other na...
#
#                                          Unnamed: 3 Unnamed: 4  \
# 0                               Low birthweight (%)        NaN
# 1                                               NaN        NaN
# 2                                        2008–2012*        NaN
# 3    Insuffisance\npondérale à la\nnaissance\n(%)\n        NaN
# 4                                               NaN        NaN
# 5                                        2008–2012*        NaN
# 6                           Bajo peso al nacer (%)         NaN
# 7                                               NaN        NaN
# 8                                        2008–2012*        NaN
# 9                                                 –        NaN
# 10                                              3.6        NaN
# 11                                                6          x
# 12                                                –        NaN
# 13                                               12          x
# 14                                                5          x
# 15                                              7.2        NaN
# 16                                                8        NaN
# 17                                                7          x
# 18                                                7          x
# 19                                               10          x
# 20                                               11          x
# 21                                                –        NaN
# 22                                               22          x
# 23                                             11.8        NaN
# 24                                                4          x
# 25                                                –        NaN
# 26                                             11.1        NaN
# 27                                               15          x
# 28                                              9.9        NaN
# 29                                                6        NaN
# ..                                              ...        ...
# 215                                         12.8291        NaN
# 216                                         14.6574        NaN
# 217                                             NaN        NaN
# 218                                             NaN        NaN
# 219                                             NaN        NaN
# 220                                             NaN        NaN
# 221                                             NaN        NaN
# 222                                             NaN        NaN
# 223                                             NaN        NaN
# 224                                             NaN        NaN
# 225                                             NaN        NaN
# 226                                             NaN        NaN
# 227                                             NaN        NaN
# 228                                             NaN        NaN
# 229                                             NaN        NaN
# 230                                             NaN        NaN
# 231                                             NaN        NaN
# 232                                             NaN        NaN
# 233                                             NaN        NaN
# 234                                             NaN        NaN
# 235                                             NaN        NaN
# 236                                             NaN        NaN
# 237                                             NaN        NaN
# 238                                             NaN        NaN
# 239                                             NaN        NaN
# 240                                             NaN        NaN
# 241                                             NaN        NaN
# 242                                             NaN        NaN
# 243                                             NaN        NaN
# 244                                             NaN        NaN
#
#                                          Unnamed: 5 Unnamed: 6  \
# 0             Early initiation of breastfeeding (%)        NaN
# 1                                               NaN        NaN
# 2                                        2008–2012*        NaN
# 3        Initiation\nprécoce de\nl’allaitement\n(%)        NaN
# 4                                               NaN        NaN
# 5                                        2008−2012*        NaN
# 6    Iniciación temprana a la lactancia materna (%)        NaN
# 7                                               NaN        NaN
# 8                                        2008−2012*        NaN
# 9                                                 –        NaN
# 10                                             42.9        NaN
# 11                                             49.5          x
# 12                                                –        NaN
# 13                                             54.9          x
# 14                                                –        NaN
# 15                                                –        NaN
# 16                                             35.7        NaN
# 17                                                –        NaN
# 18                                                –        NaN
# 19                                             31.9          x
# 20                                                –        NaN
# 21                                                –        NaN
# 22                                             47.1        NaN
# 23                                                –        NaN
# 24                                             21.1          x
# 25                                                –        NaN
# 26                                             61.5        NaN
# 27                                             50.4        NaN
# 28                                               59        NaN
# 29                                             63.8        NaN
# ..                                              ...        ...
# 215                                         53.3585        NaN
# 216                                         43.2414        NaN
# 217                                             NaN        NaN
# 218                                             NaN        NaN
# 219                                             NaN        NaN
# 220                                             NaN        NaN
# 221                                             NaN        NaN
# 222                                             NaN        NaN
# 223                                             NaN        NaN
# 224                                             NaN        NaN
# 225                                             NaN        NaN
# 226                                             NaN        NaN
# 227                                             NaN        NaN
# 228                                             NaN        NaN
# 229                                             NaN        NaN
# 230                                             NaN        NaN
# 231                                             NaN        NaN
# 232                                             NaN        NaN
# 233                                             NaN        NaN
# 234                                             NaN        NaN
# 235                                             NaN        NaN
# 236                                             NaN        NaN
# 237                                             NaN        NaN
# 238                                             NaN        NaN
# 239                                             NaN        NaN
# 240                                             NaN        NaN
# 241                                             NaN        NaN
# 242                                             NaN        NaN
# 243                                             NaN        NaN
# 244                                             NaN        NaN
#
#                                            Unnamed: 7 Unnamed: 8  \
# 0              Exclusive breastfeeding\n<6 months (%)        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3    Allaitement\nexclusivement\nau sein <6 mois\n(%)        NaN
# 4                                                 NaN        NaN
# 5                                                 NaN        NaN
# 6           Lactancia materna exclusiva\n<6 meses (%)        NaN
# 7                                                 NaN        NaN
# 8                                                 NaN        NaN
# 9                                                   –        NaN
# 10                                               38.6        NaN
# 11                                                  7          x
# 12                                                  –        NaN
# 13                                                 11          x
# 14                                                  –        NaN
# 15                                                 54        NaN
# 16                                               34.6        NaN
# 17                                                  –        NaN
# 18                                                  –        NaN
# 19                                                 12          x
# 20                                                  –        NaN
# 21                                                  –        NaN
# 22                                               64.1        NaN
# 23                                                  –        NaN
# 24                                                  9          x
# 25                                                  –        NaN
# 26                                               14.7        NaN
# 27                                               32.5        NaN
# 28                                               48.7        NaN
# 29                                               60.4        NaN
# ..                                                ...        ...
# 215                                            48.121        NaN
# 216                                                38        NaN
# 217                                               NaN        NaN
# 218                                               NaN        NaN
# 219                                               NaN        NaN
# 220                                               NaN        NaN
# 221                                               NaN        NaN
# 222                                               NaN        NaN
# 223                                               NaN        NaN
# 224                                               NaN        NaN
# 225                                               NaN        NaN
# 226                                               NaN        NaN
# 227                                               NaN        NaN
# 228                                               NaN        NaN
# 229                                               NaN        NaN
# 230                                               NaN        NaN
# 231                                               NaN        NaN
# 232                                               NaN        NaN
# 233                                               NaN        NaN
# 234                                               NaN        NaN
# 235                                               NaN        NaN
# 236                                               NaN        NaN
# 237                                               NaN        NaN
# 238                                               NaN        NaN
# 239                                               NaN        NaN
# 240                                               NaN        NaN
# 241                                               NaN        NaN
# 242                                               NaN        NaN
# 243                                               NaN        NaN
# 244                                               NaN        NaN
#
#                                             Unnamed: 9 Unnamed: 10  \
# 0    Introduction of solid, semi-solid or soft food...         NaN
# 1                                                  NaN         NaN
# 2                                                  NaN         NaN
# 3    Introduction\nd’aliments\nsolides, semisolides...         NaN
# 4                                                  NaN         NaN
# 5                                                  NaN         NaN
# 6    Incorporación de alimentos sóli- dos, semisóli...         NaN
# 7                                                  NaN         NaN
# 8                                                  NaN         NaN
# 9                                                   29           x
# 10                                             78.2788         NaN
# 11                                                  39         x,y
# 12                                                   –         NaN
# 13                                                77.2           x
# 14                                                   –         NaN
# 15                                                   –         NaN
# 16                                                  75         NaN
# 17                                                   –         NaN
# 18                                                   –         NaN
# 19                                             83.2918           x
# 20                                                   –         NaN
# 21                                                   –         NaN
# 22                                                  62         NaN
# 23                                                   –         NaN
# 24                                                38.3           x
# 25                                                   –         NaN
# 26                                                68.5         NaN
# 27                                                76.3           y
# 28                                                66.7         NaN
# 29                                              82.555         NaN
# ..                                                 ...         ...
# 215                                                 63         NaN
# 216                                            54.8513         NaN
# 217                                                NaN         NaN
# 218                                                NaN         NaN
# 219                                                NaN         NaN
# 220                                                NaN         NaN
# 221                                                NaN         NaN
# 222                                                NaN         NaN
# 223                                                NaN         NaN
# 224                                                NaN         NaN
# 225                                                NaN         NaN
# 226                                                NaN         NaN
# 227                                                NaN         NaN
# 228                                                NaN         NaN
# 229                                                NaN         NaN
# 230                                                NaN         NaN
# 231                                                NaN         NaN
# 232                                                NaN         NaN
# 233                                                NaN         NaN
# 234                                                NaN         NaN
# 235                                                NaN         NaN
# 236                                                NaN         NaN
# 237                                                NaN         NaN
# 238                                                NaN         NaN
# 239                                                NaN         NaN
# 240                                                NaN         NaN
# 241                                                NaN         NaN
# 242                                                NaN         NaN
# 243                                                NaN         NaN
# 244                                                NaN         NaN
#
#                                 Unnamed: 11     ...      \
# 0                Breastfeeding at age 2 (%)     ...
# 1                                       NaN     ...
# 2                                       NaN     ...
# 3    Nourris au sein\nà l’âge de\n2 ans (%)     ...
# 4                                       NaN     ...
# 5                                       NaN     ...
# 6        Lactancia materna a los 2 anos (%)     ...
# 7                                       NaN     ...
# 8                                       NaN     ...
# 9                                        54     ...
# 10                                       31     ...
# 11                                     22.2     ...
# 12                                        –     ...
# 13                                       37     ...
# 14                                        –     ...
# 15                                       28     ...
# 16                                     22.8     ...
# 17                                        –     ...
# 18                                        –     ...
# 19                                     16.2     ...
# 20                                        –     ...
# 21                                        –     ...
# 22                                     89.6     ...
# 23                                        –     ...
# 24                                      3.6     ...
# 25                                        –     ...
# 26                                     34.9     ...
# 27                                     92.1     ...
# 28                                     65.7     ...
# 29                                     39.8     ...
# ..                                      ...     ...
# 215                                 63.8288     ...
# 216                                 58.0455     ...
# 217                                     NaN     ...
# 218                                     NaN     ...
# 219                                     NaN     ...
# 220                                     NaN     ...
# 221                                     NaN     ...
# 222                                     NaN     ...
# 223                                     NaN     ...
# 224                                     NaN     ...
# 225                                     NaN     ...
# 226                                     NaN     ...
# 227                                     NaN     ...
# 228                                     NaN     ...
# 229                                     NaN     ...
# 230                                     NaN     ...
# 231                                     NaN     ...
# 232                                     NaN     ...
# 233                                     NaN     ...
# 234                                     NaN     ...
# 235                                     NaN     ...
# 236                                     NaN     ...
# 237                                     NaN     ...
# 238                                     NaN     ...
# 239                                     NaN     ...
# 240                                     NaN     ...
# 241                                     NaN     ...
# 242                                     NaN     ...
# 243                                     NaN     ...
# 244                                     NaN     ...
#
#                      Unnamed: 17 Unnamed: 18             Unnamed: 19  \
# 0                   Stunting (%)         NaN             Wasting (%)
# 1         moderate \nand severeθ         NaN  moderate \nand severeθ
# 2                            NaN         NaN                     NaN
# 3    Retard de\ncroissance (%)\n         NaN        Émaciation (%)\n
# 4              modérée et graveθ         NaN       modérée et graveθ
# 5                            NaN         NaN                     NaN
# 6         Cortedad de\ntalla (%)         NaN          Emaciación (%)
# 7              moderada y graveθ         NaN       moderada y graveθ
# 8                            NaN         NaN                     NaN
# 9                             59           x                       9
# 10                            19         NaN                       9
# 11                            15           x                       4
# 12                             –         NaN                       –
# 13                            29           x                     8.2
# 14                             –         NaN                       –
# 15                           8.2           x                     1.2
# 16                          19.3         NaN                       4
# 17                             –         NaN                       –
# 18                             –         NaN                       –
# 19                            25           x                       7
# 20                             –         NaN                       –
# 21                             –         NaN                       –
# 22                          41.3         NaN                    15.6
# 23                             –         NaN                       –
# 24                             4           x                       2
# 25                             –         NaN                       –
# 26                          19.3         NaN                     3.3
# 27                          44.6         NaN                      16
# 28                          33.5         NaN                     5.9
# 29                          27.1         NaN                     1.4
# ..                           ...         ...                     ...
# 215                         37.4         NaN                     9.7
# 216                         24.7         NaN                     7.8
# 217                          NaN         NaN                     NaN
# 218                          NaN         NaN                     NaN
# 219                          NaN         NaN                     NaN
# 220                          NaN         NaN                     NaN
# 221                          NaN         NaN                     NaN
# 222                          NaN         NaN                     NaN
# 223                          NaN         NaN                     NaN
# 224                          NaN         NaN                     NaN
# 225                          NaN         NaN                     NaN
# 226                          NaN         NaN                     NaN
# 227                          NaN         NaN                     NaN
# 228                          NaN         NaN                     NaN
# 229                          NaN         NaN                     NaN
# 230                          NaN         NaN                     NaN
# 231                          NaN         NaN                     NaN
# 232                          NaN         NaN                     NaN
# 233                          NaN         NaN                     NaN
# 234                          NaN         NaN                     NaN
# 235                          NaN         NaN                     NaN
# 236                          NaN         NaN                     NaN
# 237                          NaN         NaN                     NaN
# 238                          NaN         NaN                     NaN
# 239                          NaN         NaN                     NaN
# 240                          NaN         NaN                     NaN
# 241                          NaN         NaN                     NaN
# 242                          NaN         NaN                     NaN
# 243                          NaN         NaN                     NaN
# 244                          NaN         NaN                     NaN
#
#     Unnamed: 20           Unnamed: 21 Unnamed: 22  \
# 0           NaN        Overweight (%)         NaN
# 1           NaN  moderate and severeθ         NaN
# 2           NaN                   NaN         NaN
# 3           NaN        Surpoids (%)\n         NaN
# 4           NaN     modérée et graveθ         NaN
# 5           NaN                   NaN         NaN
# 6           NaN         Sobrepeso (%)         NaN
# 7           NaN     moderada y graveθ         NaN
# 8           NaN                   NaN         NaN
# 9             x                   4.6           x
# 10          NaN                  21.7         NaN
# 11            x                  12.9           x
# 12          NaN                     –         NaN
# 13            x                     –         NaN
# 14          NaN                     –         NaN
# 15            x                   9.9           x
# 16          NaN                  15.3         NaN
# 17          NaN                     –         NaN
# 18          NaN                     –         NaN
# 19            x                  12.9           x
# 20          NaN                     –         NaN
# 21          NaN                     –         NaN
# 22          NaN                   1.5         NaN
# 23          NaN                     –         NaN
# 24            x                   9.7           x
# 25          NaN                     –         NaN
# 26          NaN                   7.9         NaN
# 27          NaN                  17.9         NaN
# 28          NaN                   7.6         NaN
# 29          NaN                   8.5         NaN
# ..          ...                   ...         ...
# 215         NaN                   4.5         NaN
# 216         NaN                   6.7         NaN
# 217         NaN                   NaN         NaN
# 218         NaN                   NaN         NaN
# 219         NaN                   NaN         NaN
# 220         NaN                   NaN         NaN
# 221         NaN                   NaN         NaN
# 222         NaN                   NaN         NaN
# 223         NaN                   NaN         NaN
# 224         NaN                   NaN         NaN
# 225         NaN                   NaN         NaN
# 226         NaN                   NaN         NaN
# 227         NaN                   NaN         NaN
# 228         NaN                   NaN         NaN
# 229         NaN                   NaN         NaN
# 230         NaN                   NaN         NaN
# 231         NaN                   NaN         NaN
# 232         NaN                   NaN         NaN
# 233         NaN                   NaN         NaN
# 234         NaN                   NaN         NaN
# 235         NaN                   NaN         NaN
# 236         NaN                   NaN         NaN
# 237         NaN                   NaN         NaN
# 238         NaN                   NaN         NaN
# 239         NaN                   NaN         NaN
# 240         NaN                   NaN         NaN
# 241         NaN                   NaN         NaN
# 242         NaN                   NaN         NaN
# 243         NaN                   NaN         NaN
# 244         NaN                   NaN         NaN
#
#                                            Unnamed: 23 Unnamed: 24  \
# 0        Vitamin A supplementation, full coverageΔ (%)         NaN
# 1                                                  NaN         NaN
# 2                                                 2012         NaN
# 3    Couverture\ntotale par la\nsupplémentation en\...         NaN
# 4                                                  NaN         NaN
# 5                                                 2012         NaN
# 6    Suplementos de vitamina A cobertura completa Δ...         NaN
# 7                                                  NaN         NaN
# 8                                                 2012         NaN
# 9                                                    –         NaN
# 10                                                   –         NaN
# 11                                                   –         NaN
# 12                                                   –         NaN
# 13                                                  44         NaN
# 14                                                   –         NaN
# 15                                                   –         NaN
# 16                                                   –         NaN
# 17                                                   –         NaN
# 18                                                   –         NaN
# 19                                                  90           w
# 20                                                   –         NaN
# 21                                                   –         NaN
# 22                                                  99         NaN
# 23                                                   –         NaN
# 24                                                   –         NaN
# 25                                                   –         NaN
# 26                                                   –         NaN
# 27                                                  99         NaN
# 28                                                  43         NaN
# 29                                                  41         NaN
# ..                                                 ...         ...
# 215                                            70.4635         NaN
# 216                                            69.8144          **
# 217                                                NaN         NaN
# 218                                                NaN         NaN
# 219                                                NaN         NaN
# 220                                                NaN         NaN
# 221                                                NaN         NaN
# 222                                                NaN         NaN
# 223                                                NaN         NaN
# 224                                                NaN         NaN
# 225                                                NaN         NaN
# 226                                                NaN         NaN
# 227                                                NaN         NaN
# 228                                                NaN         NaN
# 229                                                NaN         NaN
# 230                                                NaN         NaN
# 231                                                NaN         NaN
# 232                                                NaN         NaN
# 233                                                NaN         NaN
# 234                                                NaN         NaN
# 235                                                NaN         NaN
# 236                                                NaN         NaN
# 237                                                NaN         NaN
# 238                                                NaN         NaN
# 239                                                NaN         NaN
# 240                                                NaN         NaN
# 241                                                NaN         NaN
# 242                                                NaN         NaN
# 243                                                NaN         NaN
# 244                                                NaN         NaN
#
#                        Unnamed: 25 Unnamed: 26
# 0     Iodized salt consumption (%)         NaN
# 1                              NaN         NaN
# 2                       2008–2012*         NaN
# 3    Consommation\nde sel iodé (%)         NaN
# 4                              NaN         NaN
# 5                       2008–2012*         NaN
# 6        Consumo de sal yodada (%)         NaN
# 7                              NaN         NaN
# 8                       2008–2012*         NaN
# 9                             20.4         NaN
# 10                            75.6         NaN
# 11                            60.7           x
# 12                               –         NaN
# 13                            44.7           x
# 14                               –         NaN
# 15                               –         NaN
# 16                              97           x
# 17                               –         NaN
# 18                               –         NaN
# 19                            53.8           x
# 20                               –         NaN
# 21                               –         NaN
# 22                            82.3           y
# 23                               –         NaN
# 24                               –         NaN
# 25                               –         NaN
# 26                               –         NaN
# 27                              86         NaN
# 28                            96.2         x,y
# 29                            88.7           y
# ..                             ...         ...
# 215                        60.2242         NaN
# 216                        75.5568         NaN
# 217                            NaN         NaN
# 218                            NaN         NaN
# 219                            NaN         NaN
# 220                            NaN         NaN
# 221                            NaN         NaN
# 222                            NaN         NaN
# 223                            NaN         NaN
# 224                            NaN         NaN
# 225                            NaN         NaN
# 226                            NaN         NaN
# 227                            NaN         NaN
# 228                            NaN         NaN
# 229                            NaN         NaN
# 230                            NaN         NaN
# 231                            NaN         NaN
# 232                            NaN         NaN
# 233                            NaN         NaN
# 234                            NaN         NaN
# 235                            NaN         NaN
# 236                            NaN         NaN
# 237                            NaN         NaN
# 238                            NaN         NaN
# 239                            NaN         NaN
# 240                            NaN         NaN
# 241                            NaN         NaN
# 242                            NaN         NaN
# 243                            NaN         NaN
# 244                            NaN         NaN
#
# [245 rows x 25 columns]

# %% [markdown]
# After resetting all the row indices, and if you print out the
# first 15 rows using the slicing method:
# ```
#     df[:15]
# ```
# You will find that the data we want starts from row index 9.
# The first 9 rows contain column heads in three different languages.
# As we mentioned before, to keep our script simple, we will not extract column heads here,
# rather we will delete them.
#
# Similarly, if we print out the last 50 rows,
# ```
#     df[-50:]
# ```
# The data we want ends at row 205.
# Therefore, we need to delete the first 9 rows and the
# last 39 rows, and then reindex all the rows left.

# %%
# Delete the first 9 rows
df = df.drop(df.index[0:9])
# Delete the last 39 rows
df = df.drop(df.index[-39:])
# Reindex rows
df.index = xrange(len(df.index))
df
# Out:
#                             TABLE 2. NUTRITION Unnamed: 3 Unnamed: 4  \
# 0                                  Afghanistan          –        NaN
# 1                                      Albania        3.6        NaN
# 2                                      Algeria          6          x
# 3                                      Andorra          –        NaN
# 4                                       Angola         12          x
# 5                          Antigua and Barbuda          5          x
# 6                                    Argentina        7.2        NaN
# 7                                      Armenia          8        NaN
# 8                                    Australia          7          x
# 9                                      Austria          7          x
# 10                                  Azerbaijan         10          x
# 11                                     Bahamas         11          x
# 12                                     Bahrain          –        NaN
# 13                                  Bangladesh         22          x
# 14                                    Barbados       11.8        NaN
# 15                                     Belarus          4          x
# 16                                     Belgium          –        NaN
# 17                                      Belize       11.1        NaN
# 18                                       Benin         15          x
# 19                                      Bhutan        9.9        NaN
# 20            Bolivia (Plurinational State of)          6        NaN
# 21                      Bosnia and Herzegovina        3.1        NaN
# 22                                    Botswana         13          x
# 23                                      Brazil       8.39        NaN
# 24                           Brunei Darussalam          –        NaN
# 25                                    Bulgaria        8.8        NaN
# 26                                Burkina Faso       14.1        NaN
# 27                                     Burundi       12.9        NaN
# 28                                  Cabo Verde          6          x
# 29                                    Cambodia       11.3        NaN
# ..                                         ...        ...        ...
# 167                                   Suriname       13.9        NaN
# 168                                  Swaziland        8.7        NaN
# 169                                     Sweden          –        NaN
# 170                                Switzerland          –        NaN
# 171                       Syrian Arab Republic       10.3        NaN
# 172                                 Tajikistan         10          x
# 173                                   Thailand        6.6        NaN
# 174  The former Yugoslav Republic of Macedonia        5.5        NaN
# 175                                Timor-Leste         12          x
# 176                                       Togo       11.1        NaN
# 177                                      Tonga          3          x
# 178                        Trinidad and Tobago       10.2        NaN
# 179                                    Tunisia        6.9        NaN
# 180                                     Turkey         11        NaN
# 181                               Turkmenistan          4          x
# 182                                     Tuvalu        6.1          x
# 183                                     Uganda       11.8        NaN
# 184                                    Ukraine          4          x
# 185                       United Arab Emirates        6.1        NaN
# 186                             United Kingdom          8          x
# 187                United Republic of Tanzania        8.4        NaN
# 188                              United States          8          x
# 189                                    Uruguay        8.7        NaN
# 190                                 Uzbekistan          5          x
# 191                                    Vanuatu         10          x
# 192         Venezuela (Bolivarian Republic of)          8        NaN
# 193                                   Viet Nam        5.1        NaN
# 194                                      Yemen          –        NaN
# 195                                     Zambia         11          x
# 196                                   Zimbabwe         11        NaN
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0            –        NaN          –        NaN         29           x
# 1         42.9        NaN       38.6        NaN    78.2788         NaN
# 2         49.5          x          7          x         39         x,y
# 3            –        NaN          –        NaN          –         NaN
# 4         54.9          x         11          x       77.2           x
# 5            –        NaN          –        NaN          –         NaN
# 6            –        NaN         54        NaN          –         NaN
# 7         35.7        NaN       34.6        NaN         75         NaN
# 8            –        NaN          –        NaN          –         NaN
# 9            –        NaN          –        NaN          –         NaN
# 10        31.9          x         12          x    83.2918           x
# 11           –        NaN          –        NaN          –         NaN
# 12           –        NaN          –        NaN          –         NaN
# 13        47.1        NaN       64.1        NaN         62         NaN
# 14           –        NaN          –        NaN          –         NaN
# 15        21.1          x          9          x       38.3           x
# 16           –        NaN          –        NaN          –         NaN
# 17        61.5        NaN       14.7        NaN       68.5         NaN
# 18        50.4        NaN       32.5        NaN       76.3           y
# 19          59        NaN       48.7        NaN       66.7         NaN
# 20        63.8        NaN       60.4        NaN     82.555         NaN
# 21        42.3        NaN       18.5        NaN       71.3         NaN
# 22          40          x         20          x       45.5         x,y
# 23        67.7        NaN         41        NaN       69.9         x,y
# 24           –        NaN          –        NaN          –         NaN
# 25           –        NaN          –        NaN          –         NaN
# 26        42.1        NaN       38.2        NaN       57.4         NaN
# 27        73.6        NaN       69.3        NaN       69.7           y
# 28        72.7          x         60          x         80         x,y
# 29        65.8        NaN       73.5        NaN       87.7         NaN
# ..         ...        ...        ...        ...        ...         ...
# 167       44.7        NaN        2.8        NaN         47         NaN
# 168       54.5        NaN       44.1        NaN       66.3         NaN
# 169          –        NaN          –        NaN          –         NaN
# 170          –        NaN          –        NaN          –         NaN
# 171       45.5        NaN       42.6        NaN          –         NaN
# 172       60.9          x         25          x         41           x
# 173       49.6          x       15.1        NaN          –         NaN
# 174         21        NaN         23        NaN       40.5         NaN
# 175       81.7        NaN       51.5        NaN    82.2423         NaN
# 176         46        NaN       62.4        NaN         44         NaN
# 177          –        NaN          –        NaN          –         NaN
# 178       41.2          x         13          x       83.4           x
# 179       87.4          x          6          x       61.1         x,y
# 180         39        NaN       41.6        NaN       67.5         x,y
# 181       59.8          x         11          x       53.6           x
# 182         15          x         35          x       39.6         x,y
# 183       52.5        NaN       63.2        NaN         67         NaN
# 184       40.8          x         18          x    86.4004           x
# 185          –        NaN          –        NaN          –         NaN
# 186          –        NaN          –        NaN          –         NaN
# 187       48.7        NaN       49.8        NaN    91.9154         NaN
# 188          –        NaN          –        NaN          –         NaN
# 189       59.3        NaN       65.2        NaN       34.7         x,y
# 190       67.1          x         26          x       46.6           x
# 191       71.9          x         40          x       67.8           x
# 192          –        NaN          –        NaN          –         NaN
# 193       39.7        NaN         17        NaN       50.4         NaN
# 194         30          x         12          x       76.3         x,y
# 195       56.5          x         61          x    94.3418           x
# 196       65.2        NaN       31.4        NaN         86         NaN
#
#     Unnamed: 11     ...     Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0            54     ...              59           x           9           x
# 1            31     ...              19         NaN           9         NaN
# 2          22.2     ...              15           x           4           x
# 3             –     ...               –         NaN           –         NaN
# 4            37     ...              29           x         8.2           x
# 5             –     ...               –         NaN           –         NaN
# 6            28     ...             8.2           x         1.2           x
# 7          22.8     ...            19.3         NaN           4         NaN
# 8             –     ...               –         NaN           –         NaN
# 9             –     ...               –         NaN           –         NaN
# 10         16.2     ...              25           x           7           x
# 11            –     ...               –         NaN           –         NaN
# 12            –     ...               –         NaN           –         NaN
# 13         89.6     ...            41.3         NaN        15.6         NaN
# 14            –     ...               –         NaN           –         NaN
# 15          3.6     ...               4           x           2           x
# 16            –     ...               –         NaN           –         NaN
# 17         34.9     ...            19.3         NaN         3.3         NaN
# 18         92.1     ...            44.6         NaN          16         NaN
# 19         65.7     ...            33.5         NaN         5.9         NaN
# 20         39.8     ...            27.1         NaN         1.4         NaN
# 21         12.2     ...             8.9         NaN         2.3         NaN
# 22          5.9     ...            31.4           x         7.2           x
# 23         25.2     ...               7           x           2           x
# 24            –     ...               –         NaN           –         NaN
# 25            –     ...               –         NaN           –         NaN
# 26         80.1     ...            32.9         NaN        10.9         NaN
# 27         79.1     ...            57.7         NaN         5.8         NaN
# 28         12.7     ...               –         NaN           –         NaN
# 29         43.4     ...            39.9         NaN        10.9         NaN
# ..          ...     ...             ...         ...         ...         ...
# 167        14.9     ...             8.8         NaN           5         NaN
# 168        10.7     ...            30.9         NaN         0.8         NaN
# 169           –     ...               –         NaN           –         NaN
# 170           –     ...               –         NaN           –         NaN
# 171        24.9     ...            27.5         NaN        11.5         NaN
# 172        34.2     ...            26.2         NaN         9.9         NaN
# 173           –     ...              16           x           5           x
# 174        12.8     ...             4.9         NaN         1.8         NaN
# 175        33.4     ...            58.1         NaN        18.6         NaN
# 176        63.8     ...            29.7         NaN         4.8         NaN
# 177           –     ...               –         NaN           –         NaN
# 178        22.4     ...               –         NaN           –         NaN
# 179        15.4     ...            10.1         NaN         2.8         NaN
# 180        21.6     ...            12.3         NaN         0.8         NaN
# 181        36.7     ...              19           x           7           x
# 182        50.6     ...              10           x         3.3           x
# 183        45.8     ...            33.4         NaN         4.7         NaN
# 184           6     ...               –         NaN           –         NaN
# 185           –     ...               –         NaN           –         NaN
# 186           –     ...               –         NaN           –         NaN
# 187          51     ...              42         NaN         4.8         NaN
# 188           –     ...             3.3           x         0.4           x
# 189          27     ...            14.7           x         2.4           x
# 190        37.9     ...              19           x           4           x
# 191        31.7     ...            26.3           x         5.8           x
# 192           –     ...            15.6           x           5           x
# 193        19.4     ...            22.7         NaN         4.1         NaN
# 194           –     ...            57.7           x        15.2           x
# 195        41.7     ...            45.4           x         5.2           x
# 196        19.5     ...              32         NaN           3         NaN
#
#     Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26
# 0           4.6           x           –         NaN        20.4         NaN
# 1          21.7         NaN           –         NaN        75.6         NaN
# 2          12.9           x           –         NaN        60.7           x
# 3             –         NaN           –         NaN           –         NaN
# 4             –         NaN          44         NaN        44.7           x
# 5             –         NaN           –         NaN           –         NaN
# 6           9.9           x           –         NaN           –         NaN
# 7          15.3         NaN           –         NaN          97           x
# 8             –         NaN           –         NaN           –         NaN
# 9             –         NaN           –         NaN           –         NaN
# 10         12.9           x          90           w        53.8           x
# 11            –         NaN           –         NaN           –         NaN
# 12            –         NaN           –         NaN           –         NaN
# 13          1.5         NaN          99         NaN        82.3           y
# 14            –         NaN           –         NaN           –         NaN
# 15          9.7           x           –         NaN           –         NaN
# 16            –         NaN           –         NaN           –         NaN
# 17          7.9         NaN           –         NaN           –         NaN
# 18         17.9         NaN          99         NaN          86         NaN
# 19          7.6         NaN          43         NaN        96.2         x,y
# 20          8.5         NaN          41         NaN        88.7           y
# 21         17.4         NaN           –         NaN          62         x,y
# 22         11.2           x           –         NaN        65.2           x
# 23          7.3           x           –         NaN        95.7         x,y
# 24            –         NaN           –         NaN           –         NaN
# 25            –         NaN           –         NaN         100           x
# 26          2.4         NaN          99         NaN        95.9           y
# 27          2.7         NaN           –         NaN        96.1           y
# 28            –         NaN           –         NaN        74.8         NaN
# 29          1.6         NaN          98         NaN        82.7           y
# ..          ...         ...         ...         ...         ...         ...
# 167           4         NaN           –         NaN           –         NaN
# 168        10.7         NaN          33         NaN        51.6         NaN
# 169           –         NaN           –         NaN           –         NaN
# 170           –         NaN           –         NaN           –         NaN
# 171        17.9         NaN           –         NaN        79.3           x
# 172         5.9         NaN          97         NaN        61.9         NaN
# 173           8           x           –         NaN        47.2           x
# 174        12.4         NaN           –         NaN          94         x,y
# 175         4.7         NaN          59         NaN        59.9           x
# 176         1.6         NaN          64         NaN        31.5         NaN
# 177           –         NaN           –         NaN           –         NaN
# 178           –         NaN           –         NaN        27.8           x
# 179        14.3         NaN           –         NaN        96.7           x
# 180           –         NaN           –         NaN        68.9         NaN
# 181           –         NaN           –         NaN        86.5           x
# 182         6.3           x           –         NaN           –         NaN
# 183         3.4         NaN          70         NaN          99           y
# 184           –         NaN           –         NaN        18.3           x
# 185           –         NaN           –         NaN           –         NaN
# 186           –         NaN           –         NaN           –         NaN
# 187           5         NaN          95         NaN        58.5         NaN
# 188           7           x           –         NaN           –         NaN
# 189          10           x           –         NaN           –         NaN
# 190        12.8           x          99         NaN        53.1           x
# 191         4.5           x           –         NaN        22.9           x
# 192         6.1           x           –         NaN           –         NaN
# 193         4.4         NaN          98           w        45.1         NaN
# 194           5           x          11         NaN        29.5           x
# 195         7.9           x           –         NaN        77.4           x
# 196         5.5         NaN          61         NaN          94           y
#
# [197 rows x 25 columns]

# %% [markdown]
# So far we have extracted all the records (or rows) for 196 countries in our Excel file.
# Let's set the country names as row indices, and reset the column labels.

# %%
#
# Set the country names as row indices
#
df = df.set_index(df['TABLE 2. NUTRITION'].values)
#
# Delete "TABLE 2. NUTRITION" column, it is now redundant.
#
df = df.drop('TABLE 2. NUTRITION', 1)
#
# Reindex columns
#
df.columns = list(xrange(len(df.columns))) 
df
# Out:
#                                              0    1     2    3     4    5   \
# Afghanistan                                   –  NaN     –  NaN     –  NaN
# Albania                                     3.6  NaN  42.9  NaN  38.6  NaN
# Algeria                                       6    x  49.5    x     7    x
# Andorra                                       –  NaN     –  NaN     –  NaN
# Angola                                       12    x  54.9    x    11    x
# Antigua and Barbuda                           5    x     –  NaN     –  NaN
# Argentina                                   7.2  NaN     –  NaN    54  NaN
# Armenia                                       8  NaN  35.7  NaN  34.6  NaN
# Australia                                     7    x     –  NaN     –  NaN
# Austria                                       7    x     –  NaN     –  NaN
# Azerbaijan                                   10    x  31.9    x    12    x
# Bahamas                                      11    x     –  NaN     –  NaN
# Bahrain                                       –  NaN     –  NaN     –  NaN
# Bangladesh                                   22    x  47.1  NaN  64.1  NaN
# Barbados                                   11.8  NaN     –  NaN     –  NaN
# Belarus                                       4    x  21.1    x     9    x
# Belgium                                       –  NaN     –  NaN     –  NaN
# Belize                                     11.1  NaN  61.5  NaN  14.7  NaN
# Benin                                        15    x  50.4  NaN  32.5  NaN
# Bhutan                                      9.9  NaN    59  NaN  48.7  NaN
# Bolivia (Plurinational State of)              6  NaN  63.8  NaN  60.4  NaN
# Bosnia and Herzegovina                      3.1  NaN  42.3  NaN  18.5  NaN
# Botswana                                     13    x    40    x    20    x
# Brazil                                     8.39  NaN  67.7  NaN    41  NaN
# Brunei Darussalam                             –  NaN     –  NaN     –  NaN
# Bulgaria                                    8.8  NaN     –  NaN     –  NaN
# Burkina Faso                               14.1  NaN  42.1  NaN  38.2  NaN
# Burundi                                    12.9  NaN  73.6  NaN  69.3  NaN
# Cabo Verde                                    6    x  72.7    x    60    x
# Cambodia                                   11.3  NaN  65.8  NaN  73.5  NaN
# ...                                         ...  ...   ...  ...   ...  ...
# Suriname                                   13.9  NaN  44.7  NaN   2.8  NaN
# Swaziland                                   8.7  NaN  54.5  NaN  44.1  NaN
# Sweden                                        –  NaN     –  NaN     –  NaN
# Switzerland                                   –  NaN     –  NaN     –  NaN
# Syrian Arab Republic                       10.3  NaN  45.5  NaN  42.6  NaN
# Tajikistan                                   10    x  60.9    x    25    x
# Thailand                                    6.6  NaN  49.6    x  15.1  NaN
# The former Yugoslav Republic of Macedonia   5.5  NaN    21  NaN    23  NaN
# Timor-Leste                                  12    x  81.7  NaN  51.5  NaN
# Togo                                       11.1  NaN    46  NaN  62.4  NaN
# Tonga                                         3    x     –  NaN     –  NaN
# Trinidad and Tobago                        10.2  NaN  41.2    x    13    x
# Tunisia                                     6.9  NaN  87.4    x     6    x
# Turkey                                       11  NaN    39  NaN  41.6  NaN
# Turkmenistan                                  4    x  59.8    x    11    x
# Tuvalu                                      6.1    x    15    x    35    x
# Uganda                                     11.8  NaN  52.5  NaN  63.2  NaN
# Ukraine                                       4    x  40.8    x    18    x
# United Arab Emirates                        6.1  NaN     –  NaN     –  NaN
# United Kingdom                                8    x     –  NaN     –  NaN
# United Republic of Tanzania                 8.4  NaN  48.7  NaN  49.8  NaN
# United States                                 8    x     –  NaN     –  NaN
# Uruguay                                     8.7  NaN  59.3  NaN  65.2  NaN
# Uzbekistan                                    5    x  67.1    x    26    x
# Vanuatu                                      10    x  71.9    x    40    x
# Venezuela (Bolivarian Republic of)            8  NaN     –  NaN     –  NaN
# Viet Nam                                    5.1  NaN  39.7  NaN    17  NaN
# Yemen                                         –  NaN    30    x    12    x
# Zambia                                       11    x  56.5    x    61    x
# Zimbabwe                                     11  NaN  65.2  NaN  31.4  NaN
#
#                                                 6    7     8    9  ...     14  \
# Afghanistan                                     29    x    54    x ...     59
# Albania                                    78.2788  NaN    31  NaN ...     19
# Algeria                                         39  x,y  22.2    x ...     15
# Andorra                                          –  NaN     –  NaN ...      –
# Angola                                        77.2    x    37    x ...     29
# Antigua and Barbuda                              –  NaN     –  NaN ...      –
# Argentina                                        –  NaN    28    x ...    8.2
# Armenia                                         75  NaN  22.8  NaN ...   19.3
# Australia                                        –  NaN     –  NaN ...      –
# Austria                                          –  NaN     –  NaN ...      –
# Azerbaijan                                 83.2918    x  16.2    x ...     25
# Bahamas                                          –  NaN     –  NaN ...      –
# Bahrain                                          –  NaN     –  NaN ...      –
# Bangladesh                                      62  NaN  89.6  NaN ...   41.3
# Barbados                                         –  NaN     –  NaN ...      –
# Belarus                                       38.3    x   3.6    x ...      4
# Belgium                                          –  NaN     –  NaN ...      –
# Belize                                        68.5  NaN  34.9  NaN ...   19.3
# Benin                                         76.3    y  92.1  NaN ...   44.6
# Bhutan                                        66.7  NaN  65.7  NaN ...   33.5
# Bolivia (Plurinational State of)            82.555  NaN  39.8  NaN ...   27.1
# Bosnia and Herzegovina                        71.3  NaN  12.2  NaN ...    8.9
# Botswana                                      45.5  x,y   5.9    x ...   31.4
# Brazil                                        69.9  x,y  25.2    x ...      7
# Brunei Darussalam                                –  NaN     –  NaN ...      –
# Bulgaria                                         –  NaN     –  NaN ...      –
# Burkina Faso                                  57.4  NaN  80.1  NaN ...   32.9
# Burundi                                       69.7    y  79.1  NaN ...   57.7
# Cabo Verde                                      80  x,y  12.7    x ...      –
# Cambodia                                      87.7  NaN  43.4  NaN ...   39.9
# ...                                            ...  ...   ...  ... ...    ...
# Suriname                                        47  NaN  14.9  NaN ...    8.8
# Swaziland                                     66.3  NaN  10.7  NaN ...   30.9
# Sweden                                           –  NaN     –  NaN ...      –
# Switzerland                                      –  NaN     –  NaN ...      –
# Syrian Arab Republic                             –  NaN  24.9  NaN ...   27.5
# Tajikistan                                      41    x  34.2    x ...   26.2
# Thailand                                         –  NaN     –  NaN ...     16
# The former Yugoslav Republic of Macedonia     40.5  NaN  12.8  NaN ...    4.9
# Timor-Leste                                82.2423  NaN  33.4  NaN ...   58.1
# Togo                                            44  NaN  63.8  NaN ...   29.7
# Tonga                                            –  NaN     –  NaN ...      –
# Trinidad and Tobago                           83.4    x  22.4    x ...      –
# Tunisia                                       61.1  x,y  15.4    x ...   10.1
# Turkey                                        67.5  x,y  21.6  NaN ...   12.3
# Turkmenistan                                  53.6    x  36.7    x ...     19
# Tuvalu                                        39.6  x,y  50.6    x ...     10
# Uganda                                          67  NaN  45.8  NaN ...   33.4
# Ukraine                                    86.4004    x     6    x ...      –
# United Arab Emirates                             –  NaN     –  NaN ...      –
# United Kingdom                                   –  NaN     –  NaN ...      –
# United Republic of Tanzania                91.9154  NaN    51  NaN ...     42
# United States                                    –  NaN     –  NaN ...    3.3
# Uruguay                                       34.7  x,y    27  NaN ...   14.7
# Uzbekistan                                    46.6    x  37.9    x ...     19
# Vanuatu                                       67.8    x  31.7    x ...   26.3
# Venezuela (Bolivarian Republic of)               –  NaN     –  NaN ...   15.6
# Viet Nam                                      50.4  NaN  19.4  NaN ...   22.7
# Yemen                                         76.3  x,y     –  NaN ...   57.7
# Zambia                                     94.3418    x  41.7    x ...   45.4
# Zimbabwe                                        86  NaN  19.5  NaN ...     32
#
#                                             15    16   17    18   19  20   21  \
# Afghanistan                                  x     9    x   4.6    x   –  NaN
# Albania                                    NaN     9  NaN  21.7  NaN   –  NaN
# Algeria                                      x     4    x  12.9    x   –  NaN
# Andorra                                    NaN     –  NaN     –  NaN   –  NaN
# Angola                                       x   8.2    x     –  NaN  44  NaN
# Antigua and Barbuda                        NaN     –  NaN     –  NaN   –  NaN
# Argentina                                    x   1.2    x   9.9    x   –  NaN
# Armenia                                    NaN     4  NaN  15.3  NaN   –  NaN
# Australia                                  NaN     –  NaN     –  NaN   –  NaN
# Austria                                    NaN     –  NaN     –  NaN   –  NaN
# Azerbaijan                                   x     7    x  12.9    x  90    w
# Bahamas                                    NaN     –  NaN     –  NaN   –  NaN
# Bahrain                                    NaN     –  NaN     –  NaN   –  NaN
# Bangladesh                                 NaN  15.6  NaN   1.5  NaN  99  NaN
# Barbados                                   NaN     –  NaN     –  NaN   –  NaN
# Belarus                                      x     2    x   9.7    x   –  NaN
# Belgium                                    NaN     –  NaN     –  NaN   –  NaN
# Belize                                     NaN   3.3  NaN   7.9  NaN   –  NaN
# Benin                                      NaN    16  NaN  17.9  NaN  99  NaN
# Bhutan                                     NaN   5.9  NaN   7.6  NaN  43  NaN
# Bolivia (Plurinational State of)           NaN   1.4  NaN   8.5  NaN  41  NaN
# Bosnia and Herzegovina                     NaN   2.3  NaN  17.4  NaN   –  NaN
# Botswana                                     x   7.2    x  11.2    x   –  NaN
# Brazil                                       x     2    x   7.3    x   –  NaN
# Brunei Darussalam                          NaN     –  NaN     –  NaN   –  NaN
# Bulgaria                                   NaN     –  NaN     –  NaN   –  NaN
# Burkina Faso                               NaN  10.9  NaN   2.4  NaN  99  NaN
# Burundi                                    NaN   5.8  NaN   2.7  NaN   –  NaN
# Cabo Verde                                 NaN     –  NaN     –  NaN   –  NaN
# Cambodia                                   NaN  10.9  NaN   1.6  NaN  98  NaN
# ...                                        ...   ...  ...   ...  ...  ..  ...
# Suriname                                   NaN     5  NaN     4  NaN   –  NaN
# Swaziland                                  NaN   0.8  NaN  10.7  NaN  33  NaN
# Sweden                                     NaN     –  NaN     –  NaN   –  NaN
# Switzerland                                NaN     –  NaN     –  NaN   –  NaN
# Syrian Arab Republic                       NaN  11.5  NaN  17.9  NaN   –  NaN
# Tajikistan                                 NaN   9.9  NaN   5.9  NaN  97  NaN
# Thailand                                     x     5    x     8    x   –  NaN
# The former Yugoslav Republic of Macedonia  NaN   1.8  NaN  12.4  NaN   –  NaN
# Timor-Leste                                NaN  18.6  NaN   4.7  NaN  59  NaN
# Togo                                       NaN   4.8  NaN   1.6  NaN  64  NaN
# Tonga                                      NaN     –  NaN     –  NaN   –  NaN
# Trinidad and Tobago                        NaN     –  NaN     –  NaN   –  NaN
# Tunisia                                    NaN   2.8  NaN  14.3  NaN   –  NaN
# Turkey                                     NaN   0.8  NaN     –  NaN   –  NaN
# Turkmenistan                                 x     7    x     –  NaN   –  NaN
# Tuvalu                                       x   3.3    x   6.3    x   –  NaN
# Uganda                                     NaN   4.7  NaN   3.4  NaN  70  NaN
# Ukraine                                    NaN     –  NaN     –  NaN   –  NaN
# United Arab Emirates                       NaN     –  NaN     –  NaN   –  NaN
# United Kingdom                             NaN     –  NaN     –  NaN   –  NaN
# United Republic of Tanzania                NaN   4.8  NaN     5  NaN  95  NaN
# United States                                x   0.4    x     7    x   –  NaN
# Uruguay                                      x   2.4    x    10    x   –  NaN
# Uzbekistan                                   x     4    x  12.8    x  99  NaN
# Vanuatu                                      x   5.8    x   4.5    x   –  NaN
# Venezuela (Bolivarian Republic of)           x     5    x   6.1    x   –  NaN
# Viet Nam                                   NaN   4.1  NaN   4.4  NaN  98    w
# Yemen                                        x  15.2    x     5    x  11  NaN
# Zambia                                       x   5.2    x   7.9    x   –  NaN
# Zimbabwe                                   NaN     3  NaN   5.5  NaN  61  NaN
#
#                                              22   23
# Afghanistan                                20.4  NaN
# Albania                                    75.6  NaN
# Algeria                                    60.7    x
# Andorra                                       –  NaN
# Angola                                     44.7    x
# Antigua and Barbuda                           –  NaN
# Argentina                                     –  NaN
# Armenia                                      97    x
# Australia                                     –  NaN
# Austria                                       –  NaN
# Azerbaijan                                 53.8    x
# Bahamas                                       –  NaN
# Bahrain                                       –  NaN
# Bangladesh                                 82.3    y
# Barbados                                      –  NaN
# Belarus                                       –  NaN
# Belgium                                       –  NaN
# Belize                                        –  NaN
# Benin                                        86  NaN
# Bhutan                                     96.2  x,y
# Bolivia (Plurinational State of)           88.7    y
# Bosnia and Herzegovina                       62  x,y
# Botswana                                   65.2    x
# Brazil                                     95.7  x,y
# Brunei Darussalam                             –  NaN
# Bulgaria                                    100    x
# Burkina Faso                               95.9    y
# Burundi                                    96.1    y
# Cabo Verde                                 74.8  NaN
# Cambodia                                   82.7    y
# ...                                         ...  ...
# Suriname                                      –  NaN
# Swaziland                                  51.6  NaN
# Sweden                                        –  NaN
# Switzerland                                   –  NaN
# Syrian Arab Republic                       79.3    x
# Tajikistan                                 61.9  NaN
# Thailand                                   47.2    x
# The former Yugoslav Republic of Macedonia    94  x,y
# Timor-Leste                                59.9    x
# Togo                                       31.5  NaN
# Tonga                                         –  NaN
# Trinidad and Tobago                        27.8    x
# Tunisia                                    96.7    x
# Turkey                                     68.9  NaN
# Turkmenistan                               86.5    x
# Tuvalu                                        –  NaN
# Uganda                                       99    y
# Ukraine                                    18.3    x
# United Arab Emirates                          –  NaN
# United Kingdom                                –  NaN
# United Republic of Tanzania                58.5  NaN
# United States                                 –  NaN
# Uruguay                                       –  NaN
# Uzbekistan                                 53.1    x
# Vanuatu                                    22.9    x
# Venezuela (Bolivarian Republic of)            –  NaN
# Viet Nam                                   45.1  NaN
# Yemen                                      29.5    x
# Zambia                                     77.4    x
# Zimbabwe                                     94    y
#
# [197 rows x 24 columns]

# %% [markdown]
# However, those records are still messy.
# As you can see in the printout, there are a lot of NaNs,
# and cell values with both numbers and letters (e.g., "6 x", " 39 x,y",) spread over two columns.
# Therefore, we need to merge every two columns together.
#
# How can we do that?
#
# Let us have a look at the first 10 rows and 2 columns.

# %%
df.iloc[:10, :2]
#type(df.iloc[0,1])
#type(df.iloc[0,2])
#df.dtypes
# Out:
#                        0    1
# Afghanistan            –  NaN
# Albania              3.6  NaN
# Algeria                6    x
# Andorra                –  NaN
# Angola                12    x
# Antigua and Barbuda    5    x
# Argentina            7.2  NaN
# Armenia                8  NaN
# Australia              7    x
# Austria                7    x

# %% [markdown]
# A close look at the printout will give you the following patterns:
# * If the cell contains only a float or '-', the corresponding cell value in the odd-numbered column is "NaN".
# See the rows labeled "**Afghanistan**``", "**Albania**", etc.
# * If the original cell contains a float and a couple of letters, the cell in the even-numbered column contains the float, and the one in the odd-numbered column contains the letters.
# See the rows labeled "**Algeria**", "**Angola**". etc.
#
# Assume that we are going to merge the two cells containing a float and letters respectively.
# We need a FOR loop iterating over either odd- or even-numbered columns.
# Within this FOR loop, another FOR loop is needed to iterate over rows.
# For each row, we check if the cell in the odd-numbered column contains NaN.
# If it does, we then merge it with the cell in the corresponding even-numbered column on the left.

# %%
#
# A FOR loop over odd-numbered columns
#
for col_idx in range(1, 24, 2): 
    #
    # A For loop over rows
    #
    for row_idx in xrange(len(df)):
        #
        # A IF statement to check
        #    1. If the cell value in the odd-numbered column is not NaN, then merge it the cell value in 
        #       the even-numbered column.
        #    2. Otherwise, do nothing.
        #
        if not pd.isnull(df.iloc[row_idx, col_idx]):
            df[col_idx-1][row_idx] = str(df[col_idx-1][row_idx]) + ' ' + str(df[col_idx ][row_idx])  
df
# Out:
#                                               0    1       2    3     4    5   \
# Afghanistan                                    –  NaN       –  NaN     –  NaN
# Albania                                      3.6  NaN    42.9  NaN  38.6  NaN
# Algeria                                      6 x    x  49.5 x    x   7 x    x
# Andorra                                        –  NaN       –  NaN     –  NaN
# Angola                                      12 x    x  54.9 x    x  11 x    x
# Antigua and Barbuda                          5 x    x       –  NaN     –  NaN
# Argentina                                    7.2  NaN       –  NaN    54  NaN
# Armenia                                        8  NaN    35.7  NaN  34.6  NaN
# Australia                                    7 x    x       –  NaN     –  NaN
# Austria                                      7 x    x       –  NaN     –  NaN
# Azerbaijan                                  10 x    x  31.9 x    x  12 x    x
# Bahamas                                     11 x    x       –  NaN     –  NaN
# Bahrain                                        –  NaN       –  NaN     –  NaN
# Bangladesh                                  22 x    x    47.1  NaN  64.1  NaN
# Barbados                                    11.8  NaN       –  NaN     –  NaN
# Belarus                                      4 x    x  21.1 x    x   9 x    x
# Belgium                                        –  NaN       –  NaN     –  NaN
# Belize                                      11.1  NaN    61.5  NaN  14.7  NaN
# Benin                                       15 x    x    50.4  NaN  32.5  NaN
# Bhutan                                       9.9  NaN      59  NaN  48.7  NaN
# Bolivia (Plurinational State of)               6  NaN    63.8  NaN  60.4  NaN
# Bosnia and Herzegovina                       3.1  NaN    42.3  NaN  18.5  NaN
# Botswana                                    13 x    x    40 x    x  20 x    x
# Brazil                                      8.39  NaN    67.7  NaN    41  NaN
# Brunei Darussalam                              –  NaN       –  NaN     –  NaN
# Bulgaria                                     8.8  NaN       –  NaN     –  NaN
# Burkina Faso                                14.1  NaN    42.1  NaN  38.2  NaN
# Burundi                                     12.9  NaN    73.6  NaN  69.3  NaN
# Cabo Verde                                   6 x    x  72.7 x    x  60 x    x
# Cambodia                                    11.3  NaN    65.8  NaN  73.5  NaN
# ...                                          ...  ...     ...  ...   ...  ...
# Suriname                                    13.9  NaN    44.7  NaN   2.8  NaN
# Swaziland                                    8.7  NaN    54.5  NaN  44.1  NaN
# Sweden                                         –  NaN       –  NaN     –  NaN
# Switzerland                                    –  NaN       –  NaN     –  NaN
# Syrian Arab Republic                        10.3  NaN    45.5  NaN  42.6  NaN
# Tajikistan                                  10 x    x  60.9 x    x  25 x    x
# Thailand                                     6.6  NaN  49.6 x    x  15.1  NaN
# The former Yugoslav Republic of Macedonia    5.5  NaN      21  NaN    23  NaN
# Timor-Leste                                 12 x    x    81.7  NaN  51.5  NaN
# Togo                                        11.1  NaN      46  NaN  62.4  NaN
# Tonga                                        3 x    x       –  NaN     –  NaN
# Trinidad and Tobago                         10.2  NaN  41.2 x    x  13 x    x
# Tunisia                                      6.9  NaN  87.4 x    x   6 x    x
# Turkey                                        11  NaN      39  NaN  41.6  NaN
# Turkmenistan                                 4 x    x  59.8 x    x  11 x    x
# Tuvalu                                     6.1 x    x    15 x    x  35 x    x
# Uganda                                      11.8  NaN    52.5  NaN  63.2  NaN
# Ukraine                                      4 x    x  40.8 x    x  18 x    x
# United Arab Emirates                         6.1  NaN       –  NaN     –  NaN
# United Kingdom                               8 x    x       –  NaN     –  NaN
# United Republic of Tanzania                  8.4  NaN    48.7  NaN  49.8  NaN
# United States                                8 x    x       –  NaN     –  NaN
# Uruguay                                      8.7  NaN    59.3  NaN  65.2  NaN
# Uzbekistan                                   5 x    x  67.1 x    x  26 x    x
# Vanuatu                                     10 x    x  71.9 x    x  40 x    x
# Venezuela (Bolivarian Republic of)             8  NaN       –  NaN     –  NaN
# Viet Nam                                     5.1  NaN    39.7  NaN    17  NaN
# Yemen                                          –  NaN    30 x    x  12 x    x
# Zambia                                      11 x    x  56.5 x    x  61 x    x
# Zimbabwe                                      11  NaN    65.2  NaN  31.4  NaN
#
#                                                         6    7       8    9   \
# Afghanistan                                           29 x    x    54 x    x
# Albania                                            78.2788  NaN      31  NaN
# Algeria                                             39 x,y  x,y  22.2 x    x
# Andorra                                                  –  NaN       –  NaN
# Angola                                              77.2 x    x    37 x    x
# Antigua and Barbuda                                      –  NaN       –  NaN
# Argentina                                                –  NaN    28 x    x
# Armenia                                                 75  NaN    22.8  NaN
# Australia                                                –  NaN       –  NaN
# Austria                                                  –  NaN       –  NaN
# Azerbaijan                                 83.2917648883 x    x  16.2 x    x
# Bahamas                                                  –  NaN       –  NaN
# Bahrain                                                  –  NaN       –  NaN
# Bangladesh                                              62  NaN    89.6  NaN
# Barbados                                                 –  NaN       –  NaN
# Belarus                                             38.3 x    x   3.6 x    x
# Belgium                                                  –  NaN       –  NaN
# Belize                                                68.5  NaN    34.9  NaN
# Benin                                               76.3 y    y    92.1  NaN
# Bhutan                                                66.7  NaN    65.7  NaN
# Bolivia (Plurinational State of)                    82.555  NaN    39.8  NaN
# Bosnia and Herzegovina                                71.3  NaN    12.2  NaN
# Botswana                                          45.5 x,y  x,y   5.9 x    x
# Brazil                                            69.9 x,y  x,y  25.2 x    x
# Brunei Darussalam                                        –  NaN       –  NaN
# Bulgaria                                                 –  NaN       –  NaN
# Burkina Faso                                          57.4  NaN    80.1  NaN
# Burundi                                             69.7 y    y    79.1  NaN
# Cabo Verde                                          80 x,y  x,y  12.7 x    x
# Cambodia                                              87.7  NaN    43.4  NaN
# ...                                                    ...  ...     ...  ...
# Suriname                                                47  NaN    14.9  NaN
# Swaziland                                             66.3  NaN    10.7  NaN
# Sweden                                                   –  NaN       –  NaN
# Switzerland                                              –  NaN       –  NaN
# Syrian Arab Republic                                     –  NaN    24.9  NaN
# Tajikistan                                            41 x    x  34.2 x    x
# Thailand                                                 –  NaN       –  NaN
# The former Yugoslav Republic of Macedonia             40.5  NaN    12.8  NaN
# Timor-Leste                                        82.2423  NaN    33.4  NaN
# Togo                                                    44  NaN    63.8  NaN
# Tonga                                                    –  NaN       –  NaN
# Trinidad and Tobago                                 83.4 x    x  22.4 x    x
# Tunisia                                           61.1 x,y  x,y  15.4 x    x
# Turkey                                            67.5 x,y  x,y    21.6  NaN
# Turkmenistan                                        53.6 x    x  36.7 x    x
# Tuvalu                                            39.6 x,y  x,y  50.6 x    x
# Uganda                                                  67  NaN    45.8  NaN
# Ukraine                                     86.400403369 x    x     6 x    x
# United Arab Emirates                                     –  NaN       –  NaN
# United Kingdom                                           –  NaN       –  NaN
# United Republic of Tanzania                        91.9154  NaN      51  NaN
# United States                                            –  NaN       –  NaN
# Uruguay                                           34.7 x,y  x,y      27  NaN
# Uzbekistan                                          46.6 x    x  37.9 x    x
# Vanuatu                                             67.8 x    x  31.7 x    x
# Venezuela (Bolivarian Republic of)                       –  NaN       –  NaN
# Viet Nam                                              50.4  NaN    19.4  NaN
# Yemen                                             76.3 x,y  x,y       –  NaN
# Zambia                                     94.3418013809 x    x  41.7 x    x
# Zimbabwe                                                86  NaN    19.5  NaN
#
#                                           ...       14   15      16   17  \
# Afghanistan                               ...     59 x    x     9 x    x
# Albania                                   ...       19  NaN       9  NaN
# Algeria                                   ...     15 x    x     4 x    x
# Andorra                                   ...        –  NaN       –  NaN
# Angola                                    ...     29 x    x   8.2 x    x
# Antigua and Barbuda                       ...        –  NaN       –  NaN
# Argentina                                 ...    8.2 x    x   1.2 x    x
# Armenia                                   ...     19.3  NaN       4  NaN
# Australia                                 ...        –  NaN       –  NaN
# Austria                                   ...        –  NaN       –  NaN
# Azerbaijan                                ...     25 x    x     7 x    x
# Bahamas                                   ...        –  NaN       –  NaN
# Bahrain                                   ...        –  NaN       –  NaN
# Bangladesh                                ...     41.3  NaN    15.6  NaN
# Barbados                                  ...        –  NaN       –  NaN
# Belarus                                   ...      4 x    x     2 x    x
# Belgium                                   ...        –  NaN       –  NaN
# Belize                                    ...     19.3  NaN     3.3  NaN
# Benin                                     ...     44.6  NaN      16  NaN
# Bhutan                                    ...     33.5  NaN     5.9  NaN
# Bolivia (Plurinational State of)          ...     27.1  NaN     1.4  NaN
# Bosnia and Herzegovina                    ...      8.9  NaN     2.3  NaN
# Botswana                                  ...   31.4 x    x   7.2 x    x
# Brazil                                    ...      7 x    x     2 x    x
# Brunei Darussalam                         ...        –  NaN       –  NaN
# Bulgaria                                  ...        –  NaN       –  NaN
# Burkina Faso                              ...     32.9  NaN    10.9  NaN
# Burundi                                   ...     57.7  NaN     5.8  NaN
# Cabo Verde                                ...        –  NaN       –  NaN
# Cambodia                                  ...     39.9  NaN    10.9  NaN
# ...                                       ...      ...  ...     ...  ...
# Suriname                                  ...      8.8  NaN       5  NaN
# Swaziland                                 ...     30.9  NaN     0.8  NaN
# Sweden                                    ...        –  NaN       –  NaN
# Switzerland                               ...        –  NaN       –  NaN
# Syrian Arab Republic                      ...     27.5  NaN    11.5  NaN
# Tajikistan                                ...     26.2  NaN     9.9  NaN
# Thailand                                  ...     16 x    x     5 x    x
# The former Yugoslav Republic of Macedonia ...      4.9  NaN     1.8  NaN
# Timor-Leste                               ...     58.1  NaN    18.6  NaN
# Togo                                      ...     29.7  NaN     4.8  NaN
# Tonga                                     ...        –  NaN       –  NaN
# Trinidad and Tobago                       ...        –  NaN       –  NaN
# Tunisia                                   ...     10.1  NaN     2.8  NaN
# Turkey                                    ...     12.3  NaN     0.8  NaN
# Turkmenistan                              ...     19 x    x     7 x    x
# Tuvalu                                    ...     10 x    x   3.3 x    x
# Uganda                                    ...     33.4  NaN     4.7  NaN
# Ukraine                                   ...        –  NaN       –  NaN
# United Arab Emirates                      ...        –  NaN       –  NaN
# United Kingdom                            ...        –  NaN       –  NaN
# United Republic of Tanzania               ...       42  NaN     4.8  NaN
# United States                             ...    3.3 x    x   0.4 x    x
# Uruguay                                   ...   14.7 x    x   2.4 x    x
# Uzbekistan                                ...     19 x    x     4 x    x
# Vanuatu                                   ...   26.3 x    x   5.8 x    x
# Venezuela (Bolivarian Republic of)        ...   15.6 x    x     5 x    x
# Viet Nam                                  ...     22.7  NaN     4.1  NaN
# Yemen                                     ...   57.7 x    x  15.2 x    x
# Zambia                                    ...   45.4 x    x   5.2 x    x
# Zimbabwe                                  ...       32  NaN       3  NaN
#
#                                                18   19    20   21        22  \
# Afghanistan                                 4.6 x    x     –  NaN      20.4
# Albania                                      21.7  NaN     –  NaN      75.6
# Algeria                                    12.9 x    x     –  NaN    60.7 x
# Andorra                                         –  NaN     –  NaN         –
# Angola                                          –  NaN    44  NaN    44.7 x
# Antigua and Barbuda                             –  NaN     –  NaN         –
# Argentina                                   9.9 x    x     –  NaN         –
# Armenia                                      15.3  NaN     –  NaN      97 x
# Australia                                       –  NaN     –  NaN         –
# Austria                                         –  NaN     –  NaN         –
# Azerbaijan                                 12.9 x    x  90 w    w    53.8 x
# Bahamas                                         –  NaN     –  NaN         –
# Bahrain                                         –  NaN     –  NaN         –
# Bangladesh                                    1.5  NaN    99  NaN    82.3 y
# Barbados                                        –  NaN     –  NaN         –
# Belarus                                     9.7 x    x     –  NaN         –
# Belgium                                         –  NaN     –  NaN         –
# Belize                                        7.9  NaN     –  NaN         –
# Benin                                        17.9  NaN    99  NaN        86
# Bhutan                                        7.6  NaN    43  NaN  96.2 x,y
# Bolivia (Plurinational State of)              8.5  NaN    41  NaN    88.7 y
# Bosnia and Herzegovina                       17.4  NaN     –  NaN    62 x,y
# Botswana                                   11.2 x    x     –  NaN    65.2 x
# Brazil                                      7.3 x    x     –  NaN  95.7 x,y
# Brunei Darussalam                               –  NaN     –  NaN         –
# Bulgaria                                        –  NaN     –  NaN     100 x
# Burkina Faso                                  2.4  NaN    99  NaN    95.9 y
# Burundi                                       2.7  NaN     –  NaN    96.1 y
# Cabo Verde                                      –  NaN     –  NaN      74.8
# Cambodia                                      1.6  NaN    98  NaN    82.7 y
# ...                                           ...  ...   ...  ...       ...
# Suriname                                        4  NaN     –  NaN         –
# Swaziland                                    10.7  NaN    33  NaN      51.6
# Sweden                                          –  NaN     –  NaN         –
# Switzerland                                     –  NaN     –  NaN         –
# Syrian Arab Republic                         17.9  NaN     –  NaN    79.3 x
# Tajikistan                                    5.9  NaN    97  NaN      61.9
# Thailand                                      8 x    x     –  NaN    47.2 x
# The former Yugoslav Republic of Macedonia    12.4  NaN     –  NaN    94 x,y
# Timor-Leste                                   4.7  NaN    59  NaN    59.9 x
# Togo                                          1.6  NaN    64  NaN      31.5
# Tonga                                           –  NaN     –  NaN         –
# Trinidad and Tobago                             –  NaN     –  NaN    27.8 x
# Tunisia                                      14.3  NaN     –  NaN    96.7 x
# Turkey                                          –  NaN     –  NaN      68.9
# Turkmenistan                                    –  NaN     –  NaN    86.5 x
# Tuvalu                                      6.3 x    x     –  NaN         –
# Uganda                                        3.4  NaN    70  NaN      99 y
# Ukraine                                         –  NaN     –  NaN    18.3 x
# United Arab Emirates                            –  NaN     –  NaN         –
# United Kingdom                                  –  NaN     –  NaN         –
# United Republic of Tanzania                     5  NaN    95  NaN      58.5
# United States                                 7 x    x     –  NaN         –
# Uruguay                                      10 x    x     –  NaN         –
# Uzbekistan                                 12.8 x    x    99  NaN    53.1 x
# Vanuatu                                     4.5 x    x     –  NaN    22.9 x
# Venezuela (Bolivarian Republic of)          6.1 x    x     –  NaN         –
# Viet Nam                                      4.4  NaN  98 w    w      45.1
# Yemen                                         5 x    x    11  NaN    29.5 x
# Zambia                                      7.9 x    x     –  NaN    77.4 x
# Zimbabwe                                      5.5  NaN    61  NaN      94 y
#
#                                             23
# Afghanistan                                NaN
# Albania                                    NaN
# Algeria                                      x
# Andorra                                    NaN
# Angola                                       x
# Antigua and Barbuda                        NaN
# Argentina                                  NaN
# Armenia                                      x
# Australia                                  NaN
# Austria                                    NaN
# Azerbaijan                                   x
# Bahamas                                    NaN
# Bahrain                                    NaN
# Bangladesh                                   y
# Barbados                                   NaN
# Belarus                                    NaN
# Belgium                                    NaN
# Belize                                     NaN
# Benin                                      NaN
# Bhutan                                     x,y
# Bolivia (Plurinational State of)             y
# Bosnia and Herzegovina                     x,y
# Botswana                                     x
# Brazil                                     x,y
# Brunei Darussalam                          NaN
# Bulgaria                                     x
# Burkina Faso                                 y
# Burundi                                      y
# Cabo Verde                                 NaN
# Cambodia                                     y
# ...                                        ...
# Suriname                                   NaN
# Swaziland                                  NaN
# Sweden                                     NaN
# Switzerland                                NaN
# Syrian Arab Republic                         x
# Tajikistan                                 NaN
# Thailand                                     x
# The former Yugoslav Republic of Macedonia  x,y
# Timor-Leste                                  x
# Togo                                       NaN
# Tonga                                      NaN
# Trinidad and Tobago                          x
# Tunisia                                      x
# Turkey                                     NaN
# Turkmenistan                                 x
# Tuvalu                                     NaN
# Uganda                                       y
# Ukraine                                      x
# United Arab Emirates                       NaN
# United Kingdom                             NaN
# United Republic of Tanzania                NaN
# United States                              NaN
# Uruguay                                    NaN
# Uzbekistan                                   x
# Vanuatu                                      x
# Venezuela (Bolivarian Republic of)         NaN
# Viet Nam                                   NaN
# Yemen                                        x
# Zambia                                       x
# Zimbabwe                                     y
#
# [197 rows x 24 columns]

# %% [markdown]
# The next step is to remove the odd-numbered columns in the data frame, as they are redundant now.
# To do this, we are going to use DataFrame's `drop()` function again as follows

# %%
for col_idx in range(1, 24, 2): 
        df.drop(col_idx, 1, inplace = True)
df
# Out:
#                                               0       2     4   \
# Afghanistan                                    –       –     –
# Albania                                      3.6    42.9  38.6
# Algeria                                      6 x  49.5 x   7 x
# Andorra                                        –       –     –
# Angola                                      12 x  54.9 x  11 x
# Antigua and Barbuda                          5 x       –     –
# Argentina                                    7.2       –    54
# Armenia                                        8    35.7  34.6
# Australia                                    7 x       –     –
# Austria                                      7 x       –     –
# Azerbaijan                                  10 x  31.9 x  12 x
# Bahamas                                     11 x       –     –
# Bahrain                                        –       –     –
# Bangladesh                                  22 x    47.1  64.1
# Barbados                                    11.8       –     –
# Belarus                                      4 x  21.1 x   9 x
# Belgium                                        –       –     –
# Belize                                      11.1    61.5  14.7
# Benin                                       15 x    50.4  32.5
# Bhutan                                       9.9      59  48.7
# Bolivia (Plurinational State of)               6    63.8  60.4
# Bosnia and Herzegovina                       3.1    42.3  18.5
# Botswana                                    13 x    40 x  20 x
# Brazil                                      8.39    67.7    41
# Brunei Darussalam                              –       –     –
# Bulgaria                                     8.8       –     –
# Burkina Faso                                14.1    42.1  38.2
# Burundi                                     12.9    73.6  69.3
# Cabo Verde                                   6 x  72.7 x  60 x
# Cambodia                                    11.3    65.8  73.5
# ...                                          ...     ...   ...
# Suriname                                    13.9    44.7   2.8
# Swaziland                                    8.7    54.5  44.1
# Sweden                                         –       –     –
# Switzerland                                    –       –     –
# Syrian Arab Republic                        10.3    45.5  42.6
# Tajikistan                                  10 x  60.9 x  25 x
# Thailand                                     6.6  49.6 x  15.1
# The former Yugoslav Republic of Macedonia    5.5      21    23
# Timor-Leste                                 12 x    81.7  51.5
# Togo                                        11.1      46  62.4
# Tonga                                        3 x       –     –
# Trinidad and Tobago                         10.2  41.2 x  13 x
# Tunisia                                      6.9  87.4 x   6 x
# Turkey                                        11      39  41.6
# Turkmenistan                                 4 x  59.8 x  11 x
# Tuvalu                                     6.1 x    15 x  35 x
# Uganda                                      11.8    52.5  63.2
# Ukraine                                      4 x  40.8 x  18 x
# United Arab Emirates                         6.1       –     –
# United Kingdom                               8 x       –     –
# United Republic of Tanzania                  8.4    48.7  49.8
# United States                                8 x       –     –
# Uruguay                                      8.7    59.3  65.2
# Uzbekistan                                   5 x  67.1 x  26 x
# Vanuatu                                     10 x  71.9 x  40 x
# Venezuela (Bolivarian Republic of)             8       –     –
# Viet Nam                                     5.1    39.7    17
# Yemen                                          –    30 x  12 x
# Zambia                                      11 x  56.5 x  61 x
# Zimbabwe                                      11    65.2  31.4
#
#                                                         6       8       10  \
# Afghanistan                                           29 x    54 x    33 x
# Albania                                            78.2788      31       5
# Algeria                                             39 x,y  22.2 x     3 x
# Andorra                                                  –       –       –
# Angola                                              77.2 x    37 x    16 x
# Antigua and Barbuda                                      –       –       –
# Argentina                                                –    28 x   2.3 x
# Armenia                                                 75    22.8     4.7
# Australia                                                –       –       –
# Austria                                                  –       –       –
# Azerbaijan                                 83.2917648883 x  16.2 x     8 x
# Bahamas                                                  –       –       –
# Bahrain                                                  –       –       –
# Bangladesh                                              62    89.6    36.4
# Barbados                                                 –       –       –
# Belarus                                             38.3 x   3.6 x     1 x
# Belgium                                                  –       –       –
# Belize                                                68.5    34.9     6.2
# Benin                                               76.3 y    92.1    21.3
# Bhutan                                                66.7    65.7    12.7
# Bolivia (Plurinational State of)                    82.555    39.8     4.3
# Bosnia and Herzegovina                                71.3    12.2     1.6
# Botswana                                          45.5 x,y   5.9 x  11.2 x
# Brazil                                            69.9 x,y  25.2 x     2 x
# Brunei Darussalam                                        –       –       –
# Bulgaria                                                 –       –       –
# Burkina Faso                                          57.4    80.1    24.4
# Burundi                                             69.7 y    79.1    28.8
# Cabo Verde                                          80 x,y  12.7 x       –
# Cambodia                                              87.7    43.4    28.3
# ...                                                    ...     ...     ...
# Suriname                                                47    14.9     5.8
# Swaziland                                             66.3    10.7     5.8
# Sweden                                                   –       –       –
# Switzerland                                              –       –       –
# Syrian Arab Republic                                     –    24.9    10.1
# Tajikistan                                            41 x  34.2 x    12.1
# Thailand                                                 –       –     7 x
# The former Yugoslav Republic of Macedonia             40.5    12.8     1.3
# Timor-Leste                                        82.2423    33.4    44.7
# Togo                                                    44    63.8    16.6
# Tonga                                                    –       –       –
# Trinidad and Tobago                                 83.4 x  22.4 x       –
# Tunisia                                           61.1 x,y  15.4 x     2.3
# Turkey                                            67.5 x,y    21.6     1.7
# Turkmenistan                                        53.6 x  36.7 x     8 x
# Tuvalu                                            39.6 x,y  50.6 x   1.6 x
# Uganda                                                  67    45.8    13.8
# Ukraine                                     86.400403369 x     6 x       –
# United Arab Emirates                                     –       –       –
# United Kingdom                                           –       –       –
# United Republic of Tanzania                        91.9154      51    15.8
# United States                                            –       –   1.1 x
# Uruguay                                           34.7 x,y      27   5.4 x
# Uzbekistan                                          46.6 x  37.9 x     4 x
# Vanuatu                                             67.8 x  31.7 x    11 x
# Venezuela (Bolivarian Republic of)                       –       –   3.7 x
# Viet Nam                                              50.4    19.4    11.7
# Yemen                                             76.3 x,y       –  43.1 x
# Zambia                                     94.3418013809 x  41.7 x  14.6 x
# Zimbabwe                                                86    19.5     9.7
#
#                                                12      14      16      18  \
# Afghanistan                                12.2 x    59 x     9 x   4.6 x
# Albania                                       1.7      19       9    21.7
# Algeria                                     0.9 x    15 x     4 x  12.9 x
# Andorra                                         –       –       –       –
# Angola                                      6.6 x    29 x   8.2 x       –
# Antigua and Barbuda                             –       –       –       –
# Argentina                                   0.4 x   8.2 x   1.2 x   9.9 x
# Armenia                                       1.2    19.3       4    15.3
# Australia                                       –       –       –       –
# Austria                                         –       –       –       –
# Azerbaijan                                  1.8 x    25 x     7 x  12.9 x
# Bahamas                                         –       –       –       –
# Bahrain                                         –       –       –       –
# Bangladesh                                   10.4    41.3    15.6     1.5
# Barbados                                        –       –       –       –
# Belarus                                     0.5 x     4 x     2 x   9.7 x
# Belgium                                         –       –       –       –
# Belize                                        1.3    19.3     3.3     7.9
# Benin                                         7.5    44.6      16    17.9
# Bhutan                                        3.2    33.5     5.9     7.6
# Bolivia (Plurinational State of)              0.8    27.1     1.4     8.5
# Bosnia and Herzegovina                        0.9     8.9     2.3    17.4
# Botswana                                    3.8 x  31.4 x   7.2 x  11.2 x
# Brazil                                          –     7 x     2 x   7.3 x
# Brunei Darussalam                               –       –       –       –
# Bulgaria                                        –       –       –       –
# Burkina Faso                                  6.2    32.9    10.9     2.4
# Burundi                                       7.8    57.7     5.8     2.7
# Cabo Verde                                      –       –       –       –
# Cambodia                                      6.7    39.9    10.9     1.6
# ...                                           ...     ...     ...     ...
# Suriname                                      1.3     8.8       5       4
# Swaziland                                       1    30.9     0.8    10.7
# Sweden                                          –       –       –       –
# Switzerland                                     –       –       –       –
# Syrian Arab Republic                            –    27.5    11.5    17.9
# Tajikistan                                    3.7    26.2     9.9     5.9
# Thailand                                    0.6 x    16 x     5 x     8 x
# The former Yugoslav Republic of Macedonia     0.2     4.9     1.8    12.4
# Timor-Leste                                  15.4    58.1    18.6     4.7
# Togo                                          4.2    29.7     4.8     1.6
# Tonga                                           –       –       –       –
# Trinidad and Tobago                             –       –       –       –
# Tunisia                                       0.7    10.1     2.8    14.3
# Turkey                                        0.3    12.3     0.8       –
# Turkmenistan                                1.7 x    19 x     7 x       –
# Tuvalu                                      0.3 x    10 x   3.3 x   6.3 x
# Uganda                                        3.4    33.4     4.7     3.4
# Ukraine                                         –       –       –       –
# United Arab Emirates                            –       –       –       –
# United Kingdom                                  –       –       –       –
# United Republic of Tanzania                   3.8      42     4.8       5
# United States                               0.2 x   3.3 x   0.4 x     7 x
# Uruguay                                     1.6 x  14.7 x   2.4 x    10 x
# Uzbekistan                                  0.9 x    19 x     4 x  12.8 x
# Vanuatu                                     2.1 x  26.3 x   5.8 x   4.5 x
# Venezuela (Bolivarian Republic of)              –  15.6 x     5 x   6.1 x
# Viet Nam                                      1.8    22.7     4.1     4.4
# Yemen                                      18.5 x  57.7 x  15.2 x     5 x
# Zambia                                      2.9 x  45.4 x   5.2 x   7.9 x
# Zimbabwe                                      1.9      32       3     5.5
#
#                                              20        22
# Afghanistan                                   –      20.4
# Albania                                       –      75.6
# Algeria                                       –    60.7 x
# Andorra                                       –         –
# Angola                                       44    44.7 x
# Antigua and Barbuda                           –         –
# Argentina                                     –         –
# Armenia                                       –      97 x
# Australia                                     –         –
# Austria                                       –         –
# Azerbaijan                                 90 w    53.8 x
# Bahamas                                       –         –
# Bahrain                                       –         –
# Bangladesh                                   99    82.3 y
# Barbados                                      –         –
# Belarus                                       –         –
# Belgium                                       –         –
# Belize                                        –         –
# Benin                                        99        86
# Bhutan                                       43  96.2 x,y
# Bolivia (Plurinational State of)             41    88.7 y
# Bosnia and Herzegovina                        –    62 x,y
# Botswana                                      –    65.2 x
# Brazil                                        –  95.7 x,y
# Brunei Darussalam                             –         –
# Bulgaria                                      –     100 x
# Burkina Faso                                 99    95.9 y
# Burundi                                       –    96.1 y
# Cabo Verde                                    –      74.8
# Cambodia                                     98    82.7 y
# ...                                         ...       ...
# Suriname                                      –         –
# Swaziland                                    33      51.6
# Sweden                                        –         –
# Switzerland                                   –         –
# Syrian Arab Republic                          –    79.3 x
# Tajikistan                                   97      61.9
# Thailand                                      –    47.2 x
# The former Yugoslav Republic of Macedonia     –    94 x,y
# Timor-Leste                                  59    59.9 x
# Togo                                         64      31.5
# Tonga                                         –         –
# Trinidad and Tobago                           –    27.8 x
# Tunisia                                       –    96.7 x
# Turkey                                        –      68.9
# Turkmenistan                                  –    86.5 x
# Tuvalu                                        –         –
# Uganda                                       70      99 y
# Ukraine                                       –    18.3 x
# United Arab Emirates                          –         –
# United Kingdom                                –         –
# United Republic of Tanzania                  95      58.5
# United States                                 –         –
# Uruguay                                       –         –
# Uzbekistan                                   99    53.1 x
# Vanuatu                                       –    22.9 x
# Venezuela (Bolivarian Republic of)            –         –
# Viet Nam                                   98 w      45.1
# Yemen                                        11    29.5 x
# Zambia                                        –    77.4 x
# Zimbabwe                                     61      94 y
#
# [197 rows x 12 columns]

# %% [markdown]
# Now the data is in a pretty good shape aside from the column heads.
# We can reindex all the columns with integers, or you can extract
# the column heads from the Excel file using either manual or programmatic method.
# Here we are going to use integers.

# %%
df.columns = xrange(len(df.columns))
df
# Out:
#                                               0       1     2   \
# Afghanistan                                    –       –     –
# Albania                                      3.6    42.9  38.6
# Algeria                                      6 x  49.5 x   7 x
# Andorra                                        –       –     –
# Angola                                      12 x  54.9 x  11 x
# Antigua and Barbuda                          5 x       –     –
# Argentina                                    7.2       –    54
# Armenia                                        8    35.7  34.6
# Australia                                    7 x       –     –
# Austria                                      7 x       –     –
# Azerbaijan                                  10 x  31.9 x  12 x
# Bahamas                                     11 x       –     –
# Bahrain                                        –       –     –
# Bangladesh                                  22 x    47.1  64.1
# Barbados                                    11.8       –     –
# Belarus                                      4 x  21.1 x   9 x
# Belgium                                        –       –     –
# Belize                                      11.1    61.5  14.7
# Benin                                       15 x    50.4  32.5
# Bhutan                                       9.9      59  48.7
# Bolivia (Plurinational State of)               6    63.8  60.4
# Bosnia and Herzegovina                       3.1    42.3  18.5
# Botswana                                    13 x    40 x  20 x
# Brazil                                      8.39    67.7    41
# Brunei Darussalam                              –       –     –
# Bulgaria                                     8.8       –     –
# Burkina Faso                                14.1    42.1  38.2
# Burundi                                     12.9    73.6  69.3
# Cabo Verde                                   6 x  72.7 x  60 x
# Cambodia                                    11.3    65.8  73.5
# ...                                          ...     ...   ...
# Suriname                                    13.9    44.7   2.8
# Swaziland                                    8.7    54.5  44.1
# Sweden                                         –       –     –
# Switzerland                                    –       –     –
# Syrian Arab Republic                        10.3    45.5  42.6
# Tajikistan                                  10 x  60.9 x  25 x
# Thailand                                     6.6  49.6 x  15.1
# The former Yugoslav Republic of Macedonia    5.5      21    23
# Timor-Leste                                 12 x    81.7  51.5
# Togo                                        11.1      46  62.4
# Tonga                                        3 x       –     –
# Trinidad and Tobago                         10.2  41.2 x  13 x
# Tunisia                                      6.9  87.4 x   6 x
# Turkey                                        11      39  41.6
# Turkmenistan                                 4 x  59.8 x  11 x
# Tuvalu                                     6.1 x    15 x  35 x
# Uganda                                      11.8    52.5  63.2
# Ukraine                                      4 x  40.8 x  18 x
# United Arab Emirates                         6.1       –     –
# United Kingdom                               8 x       –     –
# United Republic of Tanzania                  8.4    48.7  49.8
# United States                                8 x       –     –
# Uruguay                                      8.7    59.3  65.2
# Uzbekistan                                   5 x  67.1 x  26 x
# Vanuatu                                     10 x  71.9 x  40 x
# Venezuela (Bolivarian Republic of)             8       –     –
# Viet Nam                                     5.1    39.7    17
# Yemen                                          –    30 x  12 x
# Zambia                                      11 x  56.5 x  61 x
# Zimbabwe                                      11    65.2  31.4
#
#                                                         3       4       5   \
# Afghanistan                                           29 x    54 x    33 x
# Albania                                            78.2788      31       5
# Algeria                                             39 x,y  22.2 x     3 x
# Andorra                                                  –       –       –
# Angola                                              77.2 x    37 x    16 x
# Antigua and Barbuda                                      –       –       –
# Argentina                                                –    28 x   2.3 x
# Armenia                                                 75    22.8     4.7
# Australia                                                –       –       –
# Austria                                                  –       –       –
# Azerbaijan                                 83.2917648883 x  16.2 x     8 x
# Bahamas                                                  –       –       –
# Bahrain                                                  –       –       –
# Bangladesh                                              62    89.6    36.4
# Barbados                                                 –       –       –
# Belarus                                             38.3 x   3.6 x     1 x
# Belgium                                                  –       –       –
# Belize                                                68.5    34.9     6.2
# Benin                                               76.3 y    92.1    21.3
# Bhutan                                                66.7    65.7    12.7
# Bolivia (Plurinational State of)                    82.555    39.8     4.3
# Bosnia and Herzegovina                                71.3    12.2     1.6
# Botswana                                          45.5 x,y   5.9 x  11.2 x
# Brazil                                            69.9 x,y  25.2 x     2 x
# Brunei Darussalam                                        –       –       –
# Bulgaria                                                 –       –       –
# Burkina Faso                                          57.4    80.1    24.4
# Burundi                                             69.7 y    79.1    28.8
# Cabo Verde                                          80 x,y  12.7 x       –
# Cambodia                                              87.7    43.4    28.3
# ...                                                    ...     ...     ...
# Suriname                                                47    14.9     5.8
# Swaziland                                             66.3    10.7     5.8
# Sweden                                                   –       –       –
# Switzerland                                              –       –       –
# Syrian Arab Republic                                     –    24.9    10.1
# Tajikistan                                            41 x  34.2 x    12.1
# Thailand                                                 –       –     7 x
# The former Yugoslav Republic of Macedonia             40.5    12.8     1.3
# Timor-Leste                                        82.2423    33.4    44.7
# Togo                                                    44    63.8    16.6
# Tonga                                                    –       –       –
# Trinidad and Tobago                                 83.4 x  22.4 x       –
# Tunisia                                           61.1 x,y  15.4 x     2.3
# Turkey                                            67.5 x,y    21.6     1.7
# Turkmenistan                                        53.6 x  36.7 x     8 x
# Tuvalu                                            39.6 x,y  50.6 x   1.6 x
# Uganda                                                  67    45.8    13.8
# Ukraine                                     86.400403369 x     6 x       –
# United Arab Emirates                                     –       –       –
# United Kingdom                                           –       –       –
# United Republic of Tanzania                        91.9154      51    15.8
# United States                                            –       –   1.1 x
# Uruguay                                           34.7 x,y      27   5.4 x
# Uzbekistan                                          46.6 x  37.9 x     4 x
# Vanuatu                                             67.8 x  31.7 x    11 x
# Venezuela (Bolivarian Republic of)                       –       –   3.7 x
# Viet Nam                                              50.4    19.4    11.7
# Yemen                                             76.3 x,y       –  43.1 x
# Zambia                                     94.3418013809 x  41.7 x  14.6 x
# Zimbabwe                                                86    19.5     9.7
#
#                                                6       7       8       9   \
# Afghanistan                                12.2 x    59 x     9 x   4.6 x
# Albania                                       1.7      19       9    21.7
# Algeria                                     0.9 x    15 x     4 x  12.9 x
# Andorra                                         –       –       –       –
# Angola                                      6.6 x    29 x   8.2 x       –
# Antigua and Barbuda                             –       –       –       –
# Argentina                                   0.4 x   8.2 x   1.2 x   9.9 x
# Armenia                                       1.2    19.3       4    15.3
# Australia                                       –       –       –       –
# Austria                                         –       –       –       –
# Azerbaijan                                  1.8 x    25 x     7 x  12.9 x
# Bahamas                                         –       –       –       –
# Bahrain                                         –       –       –       –
# Bangladesh                                   10.4    41.3    15.6     1.5
# Barbados                                        –       –       –       –
# Belarus                                     0.5 x     4 x     2 x   9.7 x
# Belgium                                         –       –       –       –
# Belize                                        1.3    19.3     3.3     7.9
# Benin                                         7.5    44.6      16    17.9
# Bhutan                                        3.2    33.5     5.9     7.6
# Bolivia (Plurinational State of)              0.8    27.1     1.4     8.5
# Bosnia and Herzegovina                        0.9     8.9     2.3    17.4
# Botswana                                    3.8 x  31.4 x   7.2 x  11.2 x
# Brazil                                          –     7 x     2 x   7.3 x
# Brunei Darussalam                               –       –       –       –
# Bulgaria                                        –       –       –       –
# Burkina Faso                                  6.2    32.9    10.9     2.4
# Burundi                                       7.8    57.7     5.8     2.7
# Cabo Verde                                      –       –       –       –
# Cambodia                                      6.7    39.9    10.9     1.6
# ...                                           ...     ...     ...     ...
# Suriname                                      1.3     8.8       5       4
# Swaziland                                       1    30.9     0.8    10.7
# Sweden                                          –       –       –       –
# Switzerland                                     –       –       –       –
# Syrian Arab Republic                            –    27.5    11.5    17.9
# Tajikistan                                    3.7    26.2     9.9     5.9
# Thailand                                    0.6 x    16 x     5 x     8 x
# The former Yugoslav Republic of Macedonia     0.2     4.9     1.8    12.4
# Timor-Leste                                  15.4    58.1    18.6     4.7
# Togo                                          4.2    29.7     4.8     1.6
# Tonga                                           –       –       –       –
# Trinidad and Tobago                             –       –       –       –
# Tunisia                                       0.7    10.1     2.8    14.3
# Turkey                                        0.3    12.3     0.8       –
# Turkmenistan                                1.7 x    19 x     7 x       –
# Tuvalu                                      0.3 x    10 x   3.3 x   6.3 x
# Uganda                                        3.4    33.4     4.7     3.4
# Ukraine                                         –       –       –       –
# United Arab Emirates                            –       –       –       –
# United Kingdom                                  –       –       –       –
# United Republic of Tanzania                   3.8      42     4.8       5
# United States                               0.2 x   3.3 x   0.4 x     7 x
# Uruguay                                     1.6 x  14.7 x   2.4 x    10 x
# Uzbekistan                                  0.9 x    19 x     4 x  12.8 x
# Vanuatu                                     2.1 x  26.3 x   5.8 x   4.5 x
# Venezuela (Bolivarian Republic of)              –  15.6 x     5 x   6.1 x
# Viet Nam                                      1.8    22.7     4.1     4.4
# Yemen                                      18.5 x  57.7 x  15.2 x     5 x
# Zambia                                      2.9 x  45.4 x   5.2 x   7.9 x
# Zimbabwe                                      1.9      32       3     5.5
#
#                                              10        11
# Afghanistan                                   –      20.4
# Albania                                       –      75.6
# Algeria                                       –    60.7 x
# Andorra                                       –         –
# Angola                                       44    44.7 x
# Antigua and Barbuda                           –         –
# Argentina                                     –         –
# Armenia                                       –      97 x
# Australia                                     –         –
# Austria                                       –         –
# Azerbaijan                                 90 w    53.8 x
# Bahamas                                       –         –
# Bahrain                                       –         –
# Bangladesh                                   99    82.3 y
# Barbados                                      –         –
# Belarus                                       –         –
# Belgium                                       –         –
# Belize                                        –         –
# Benin                                        99        86
# Bhutan                                       43  96.2 x,y
# Bolivia (Plurinational State of)             41    88.7 y
# Bosnia and Herzegovina                        –    62 x,y
# Botswana                                      –    65.2 x
# Brazil                                        –  95.7 x,y
# Brunei Darussalam                             –         –
# Bulgaria                                      –     100 x
# Burkina Faso                                 99    95.9 y
# Burundi                                       –    96.1 y
# Cabo Verde                                    –      74.8
# Cambodia                                     98    82.7 y
# ...                                         ...       ...
# Suriname                                      –         –
# Swaziland                                    33      51.6
# Sweden                                        –         –
# Switzerland                                   –         –
# Syrian Arab Republic                          –    79.3 x
# Tajikistan                                   97      61.9
# Thailand                                      –    47.2 x
# The former Yugoslav Republic of Macedonia     –    94 x,y
# Timor-Leste                                  59    59.9 x
# Togo                                         64      31.5
# Tonga                                         –         –
# Trinidad and Tobago                           –    27.8 x
# Tunisia                                       –    96.7 x
# Turkey                                        –      68.9
# Turkmenistan                                  –    86.5 x
# Tuvalu                                        –         –
# Uganda                                       70      99 y
# Ukraine                                       –    18.3 x
# United Arab Emirates                          –         –
# United Kingdom                                –         –
# United Republic of Tanzania                  95      58.5
# United States                                 –         –
# Uruguay                                       –         –
# Uzbekistan                                   99    53.1 x
# Vanuatu                                       –    22.9 x
# Venezuela (Bolivarian Republic of)            –         –
# Viet Nam                                   98 w      45.1
# Yemen                                        11    29.5 x
# Zambia                                        –    77.4 x
# Zimbabwe                                     61      94 y
#
# [197 rows x 12 columns]

# %% [markdown]
# Finally, we have extracted the data table from our Excel file, and put it into a Pandas DataFrame.
# The DataFrame has 197 rows and 12 columns, where rows correspond to records for individual countries
# and columns are variables (or attributes).
# Our last step is to save the data table in a CSV file.

# %%
df.to_csv('./en_final_table_2.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-15-865e3fe9bd67> in <module>()
# ----> 1 df.to_csv('./en_final_table_2.csv')
#
# /Users/Ash/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal, **kwds)
#    1341                                      doublequote=doublequote,
#    1342                                      escapechar=escapechar, decimal=decimal)
# -> 1343         formatter.save()
#    1344
#    1345         if path_or_buf is None:
#
# /Users/Ash/anaconda2/lib/python2.7/site-packages/pandas/core/format.pyc in save(self)
#    1548
#    1549             else:
# -> 1550                 self._save()
#    1551
#    1552         finally:
#
# /Users/Ash/anaconda2/lib/python2.7/site-packages/pandas/core/format.pyc in _save(self)
#    1649                 break
#    1650
# -> 1651             self._save_chunk(start_i, end_i)
#    1652
#    1653     def _save_chunk(self, start_i, end_i):
#
# /Users/Ash/anaconda2/lib/python2.7/site-packages/pandas/core/format.pyc in _save_chunk(self, start_i, end_i)
#    1675                                         quoting=self.quoting)
#    1676
# -> 1677         lib.write_csv_rows(self.data, ix, self.nlevels, self.cols, self.writer)
#    1678
#    1679 # from collections import namedtuple
#
# pandas/lib.pyx in pandas.lib.write_csv_rows (pandas/lib.c:19470)()
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\u2013' in position 0: ordinal not in range(128)

# %% [markdown]
# What is the problem you get? Let's check the type of some values in the DataFrame using
# ```
#     type(df.iloc[i,j])
# ```
# where i indicates row index, and j indicates column index.
# You will find that DataFrame's `read_excel` method has parsed all strings and special characters,
# like '-', into Unicode objects.
# If you print the DataFrame, however, you'll get the printed version of the Unicode.
# In contrast, printing a value in a specific location, for example,
# ```python
#     df.iloc[0,0]
# ```
# gives you the original Unicode,
# ```
#     u'\u2013'
# ```
# Therefore, you need to specify the encoding method while saving
# the DataFrame into a CSV file.

# %%
df.to_csv('./en_final_table_2.csv', sep='\t', encoding='utf-32')

# %% [markdown]
# ## 3. Summary
# Compared with the three formats discussed in previous chapters,
# Excel files are not meant to be read by programming languages, but they can still be parsed with a bit more effort.
# In this chapter, you have learnt how to extract data from an Excel file and save
# the extracted data in a CSV file using Pandas ExcelFile class and various
# methods for manipulating DataFrame.
#
# ## 4. Exercise
# 1. In the introduction, we have mentioned a couple of Python libraries that can be
# use to manipulate Excel files. Here we suggest that you download and install `openpyxl`,
# and try to write your own Python script to parse the same Excel file, and store the data in the
# same format as in Section 2.
